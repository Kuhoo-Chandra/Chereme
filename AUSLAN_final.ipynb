# %% [markdown]
# <a href="https://colab.research.google.com/github/Kuhoo-Chandra/Chereme/blob/main/AUSLAN_final.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
! pip install kaggle
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: kaggle in /usr/local/lib/python3.8/dist-packages (1.5.12)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.8/dist-packages (from kaggle) (4.64.1)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.8/dist-packages (from kaggle) (2.8.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.8/dist-packages (from kaggle) (2.25.1)
# Requirement already satisfied: six>=1.10 in /usr/local/lib/python3.8/dist-packages (from kaggle) (1.15.0)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.8/dist-packages (from kaggle) (1.24.3)
# Requirement already satisfied: certifi in /usr/local/lib/python3.8/dist-packages (from kaggle) (2022.12.7)
# Requirement already satisfied: python-slugify in /usr/local/lib/python3.8/dist-packages (from kaggle) (7.0.0)
# Requirement already satisfied: text-unidecode>=1.3 in /usr/local/lib/python3.8/dist-packages (from python-slugify->kaggle) (1.3)
# Requirement already satisfied: chardet<5,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests->kaggle) (4.0.0)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests->kaggle) (2.10)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
mkdir ~/.kaggle

# %%
# !chmod 600 ~/.kaggle/kaggle.json
# Out:
# chmod: cannot access '/root/.kaggle/kaggle.json': No such file or directory

# %%
# !cp /content/drive/MyDrive/Chereme/DATASET/kaggle.json ~/.kaggle/kaggle.json

# %%
! kaggle datasets download rithwikchhugani/auslan-sign-language-fingerspelling-dataset
# Out:
# Downloading auslan-sign-language-fingerspelling-dataset.zip to /content
# 100% 5.60G/5.60G [00:59<00:00, 140MB/s]
# 100% 5.60G/5.60G [00:59<00:00, 101MB/s]

# %%
! unzip auslan-sign-language-fingerspelling-dataset.zip
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: dataset_R_G_blur/X/X1 (2).jpg
#   inflating: dataset_R_G_blur/X/X1.jpg
#   inflating: dataset_R_G_blur/X/X10 (2).jpg
#   inflating: dataset_R_G_blur/X/X10.jpg
#   inflating: dataset_R_G_blur/X/X100 (2).jpg
#   inflating: dataset_R_G_blur/X/X100.jpg
#   inflating: dataset_R_G_blur/X/X101 (2).jpg
#   inflating: dataset_R_G_blur/X/X101.jpg
#   inflating: dataset_R_G_blur/X/X102 (2).jpg
#   inflating: dataset_R_G_blur/X/X102.jpg
#   inflating: dataset_R_G_blur/X/X103 (2).jpg
#   inflating: dataset_R_G_blur/X/X103.jpg
#   inflating: dataset_R_G_blur/X/X104 (2).jpg
#   inflating: dataset_R_G_blur/X/X104.jpg
#   inflating: dataset_R_G_blur/X/X105 (2).jpg
#   inflating: dataset_R_G_blur/X/X105.jpg
#   inflating: dataset_R_G_blur/X/X106 (2).jpg
#   inflating: dataset_R_G_blur/X/X106.jpg
#   inflating: dataset_R_G_blur/X/X107 (2).jpg
#   inflating: dataset_R_G_blur/X/X107.jpg
#   inflating: dataset_R_G_blur/X/X108 (2).jpg
#   inflating: dataset_R_G_blur/X/X108.jpg
#   inflating: dataset_R_G_blur/X/X109 (2).jpg
#   inflating: dataset_R_G_blur/X/X109.jpg
#   inflating: dataset_R_G_blur/X/X11 (2).jpg
#   inflating: dataset_R_G_blur/X/X11.jpg
#   inflating: dataset_R_G_blur/X/X110 (2).jpg
#   inflating: dataset_R_G_blur/X/X110.jpg
#   inflating: dataset_R_G_blur/X/X111 (2).jpg
#   inflating: dataset_R_G_blur/X/X111.jpg
#   inflating: dataset_R_G_blur/X/X112 (2).jpg
#   inflating: dataset_R_G_blur/X/X112.jpg
#   inflating: dataset_R_G_blur/X/X113 (2).jpg
#   inflating: dataset_R_G_blur/X/X113.jpg
#   inflating: dataset_R_G_blur/X/X114 (2).jpg
#   inflating: dataset_R_G_blur/X/X114.jpg
#   inflating: dataset_R_G_blur/X/X115 (2).jpg
#   inflating: dataset_R_G_blur/X/X115.jpg
#   inflating: dataset_R_G_blur/X/X116 (2).jpg
#   inflating: dataset_R_G_blur/X/X116.jpg
#   inflating: dataset_R_G_blur/X/X117 (2).jpg
#   inflating: dataset_R_G_blur/X/X117.jpg
#   inflating: dataset_R_G_blur/X/X118 (2).jpg
#   inflating: dataset_R_G_blur/X/X118.jpg
#   inflating: dataset_R_G_blur/X/X119 (2).jpg
#   inflating: dataset_R_G_blur/X/X119.jpg
#   inflating: dataset_R_G_blur/X/X12 (2).jpg
#   inflating: dataset_R_G_blur/X/X12.jpg
#   inflating: dataset_R_G_blur/X/X120 (2).jpg
#   inflating: dataset_R_G_blur/X/X120.jpg
#   inflating: dataset_R_G_blur/X/X121 (2).jpg
#   inflating: dataset_R_G_blur/X/X121.jpg
#   inflating: dataset_R_G_blur/X/X122 (2).jpg
#   inflating: dataset_R_G_blur/X/X122.jpg
#   inflating: dataset_R_G_blur/X/X123 (2).jpg
#   inflating: dataset_R_G_blur/X/X123.jpg
#   inflating: dataset_R_G_blur/X/X124 (2).jpg
#   inflating: dataset_R_G_blur/X/X124.jpg
#   inflating: dataset_R_G_blur/X/X125 (2).jpg
#   inflating: dataset_R_G_blur/X/X125.jpg
#   inflating: dataset_R_G_blur/X/X126 (2).jpg
#   inflating: dataset_R_G_blur/X/X126.jpg
#   inflating: dataset_R_G_blur/X/X127 (2).jpg
#   inflating: dataset_R_G_blur/X/X127.jpg
#   inflating: dataset_R_G_blur/X/X128 (2).jpg
#   inflating: dataset_R_G_blur/X/X128.jpg
#   inflating: dataset_R_G_blur/X/X129 (2).jpg
#   inflating: dataset_R_G_blur/X/X129.jpg
#   inflating: dataset_R_G_blur/X/X13 (2).jpg
#   inflating: dataset_R_G_blur/X/X13.jpg
#   inflating: dataset_R_G_blur/X/X130 (2).jpg
#   inflating: dataset_R_G_blur/X/X130.jpg
#   inflating: dataset_R_G_blur/X/X131 (2).jpg
#   inflating: dataset_R_G_blur/X/X131.jpg
#   inflating: dataset_R_G_blur/X/X132 (2).jpg
#   inflating: dataset_R_G_blur/X/X132.jpg
#   inflating: dataset_R_G_blur/X/X133 (2).jpg
#   inflating: dataset_R_G_blur/X/X133.jpg
#   inflating: dataset_R_G_blur/X/X134 (2).jpg
#   inflating: dataset_R_G_blur/X/X134.jpg
#   inflating: dataset_R_G_blur/X/X135 (2).jpg
#   inflating: dataset_R_G_blur/X/X135.jpg
#   inflating: dataset_R_G_blur/X/X136 (2).jpg
#   inflating: dataset_R_G_blur/X/X136.jpg
#   inflating: dataset_R_G_blur/X/X137 (2).jpg
#   inflating: dataset_R_G_blur/X/X137.jpg
#   inflating: dataset_R_G_blur/X/X138 (2).jpg
#   inflating: dataset_R_G_blur/X/X138.jpg
#   inflating: dataset_R_G_blur/X/X139 (2).jpg
#   inflating: dataset_R_G_blur/X/X139.jpg
#   inflating: dataset_R_G_blur/X/X14 (2).jpg
#   inflating: dataset_R_G_blur/X/X14.jpg
#   inflating: dataset_R_G_blur/X/X140 (2).jpg
#   inflating: dataset_R_G_blur/X/X140.jpg
#   inflating: dataset_R_G_blur/X/X141 (2).jpg
#   inflating: dataset_R_G_blur/X/X141.jpg
#   inflating: dataset_R_G_blur/X/X142 (2).jpg
#   inflating: dataset_R_G_blur/X/X142.jpg
#   inflating: dataset_R_G_blur/X/X143 (2).jpg
#   inflating: dataset_R_G_blur/X/X143.jpg
#   inflating: dataset_R_G_blur/X/X144 (2).jpg
#   inflating: dataset_R_G_blur/X/X144.jpg
#   inflating: dataset_R_G_blur/X/X145 (2).jpg
#   inflating: dataset_R_G_blur/X/X145.jpg
#   inflating: dataset_R_G_blur/X/X146 (2).jpg
#   inflating: dataset_R_G_blur/X/X146.jpg
#   inflating: dataset_R_G_blur/X/X147 (2).jpg
#   inflating: dataset_R_G_blur/X/X147.jpg
#   inflating: dataset_R_G_blur/X/X148 (2).jpg
#   inflating: dataset_R_G_blur/X/X148.jpg
#   inflating: dataset_R_G_blur/X/X149 (2).jpg
#   inflating: dataset_R_G_blur/X/X149.jpg
#   inflating: dataset_R_G_blur/X/X15 (2).jpg
#   inflating: dataset_R_G_blur/X/X15.jpg
#   inflating: dataset_R_G_blur/X/X150 (2).jpg
#   inflating: dataset_R_G_blur/X/X150.jpg
#   inflating: dataset_R_G_blur/X/X151 (2).jpg
#   inflating: dataset_R_G_blur/X/X151.jpg
#   inflating: dataset_R_G_blur/X/X152 (2).jpg
#   inflating: dataset_R_G_blur/X/X152.jpg
#   inflating: dataset_R_G_blur/X/X153 (2).jpg
#   inflating: dataset_R_G_blur/X/X153.jpg
#   inflating: dataset_R_G_blur/X/X154 (2).jpg
#   inflating: dataset_R_G_blur/X/X154.jpg
#   inflating: dataset_R_G_blur/X/X155 (2).jpg
#   inflating: dataset_R_G_blur/X/X155.jpg
#   inflating: dataset_R_G_blur/X/X156 (2).jpg
#   inflating: dataset_R_G_blur/X/X156.jpg
#   inflating: dataset_R_G_blur/X/X157 (2).jpg
#   inflating: dataset_R_G_blur/X/X157.jpg
#   inflating: dataset_R_G_blur/X/X158 (2).jpg
#   inflating: dataset_R_G_blur/X/X158.jpg
#   inflating: dataset_R_G_blur/X/X159 (2).jpg
#   inflating: dataset_R_G_blur/X/X159.jpg
#   inflating: dataset_R_G_blur/X/X16 (2).jpg
#   inflating: dataset_R_G_blur/X/X16.jpg
#   inflating: dataset_R_G_blur/X/X160 (2).jpg
#   inflating: dataset_R_G_blur/X/X160.jpg
#   inflating: dataset_R_G_blur/X/X161 (2).jpg
#   inflating: dataset_R_G_blur/X/X161.jpg
#   inflating: dataset_R_G_blur/X/X162 (2).jpg
#   inflating: dataset_R_G_blur/X/X162.jpg
#   inflating: dataset_R_G_blur/X/X163 (2).jpg
#   inflating: dataset_R_G_blur/X/X163.jpg
#   inflating: dataset_R_G_blur/X/X164 (2).jpg
#   inflating: dataset_R_G_blur/X/X164.jpg
#   inflating: dataset_R_G_blur/X/X165 (2).jpg
#   inflating: dataset_R_G_blur/X/X165.jpg
#   inflating: dataset_R_G_blur/X/X166 (2).jpg
#   inflating: dataset_R_G_blur/X/X166.jpg
#   inflating: dataset_R_G_blur/X/X167 (2).jpg
#   inflating: dataset_R_G_blur/X/X167.jpg
#   inflating: dataset_R_G_blur/X/X168 (2).jpg
#   inflating: dataset_R_G_blur/X/X168.jpg
#   inflating: dataset_R_G_blur/X/X169 (2).jpg
#   inflating: dataset_R_G_blur/X/X169.jpg
#   inflating: dataset_R_G_blur/X/X17 (2).jpg
#   inflating: dataset_R_G_blur/X/X17.jpg
#   inflating: dataset_R_G_blur/X/X170 (2).jpg
#   inflating: dataset_R_G_blur/X/X170.jpg
#   inflating: dataset_R_G_blur/X/X171 (2).jpg
#   inflating: dataset_R_G_blur/X/X171.jpg
#   inflating: dataset_R_G_blur/X/X172 (2).jpg
#   inflating: dataset_R_G_blur/X/X172.jpg
#   inflating: dataset_R_G_blur/X/X173 (2).jpg
#   inflating: dataset_R_G_blur/X/X173.jpg
#   inflating: dataset_R_G_blur/X/X174 (2).jpg
#   inflating: dataset_R_G_blur/X/X174.jpg
#   inflating: dataset_R_G_blur/X/X175 (2).jpg
#   inflating: dataset_R_G_blur/X/X175.jpg
#   inflating: dataset_R_G_blur/X/X176 (2).jpg
#   inflating: dataset_R_G_blur/X/X176.jpg
#   inflating: dataset_R_G_blur/X/X177 (2).jpg
#   inflating: dataset_R_G_blur/X/X177.jpg
#   inflating: dataset_R_G_blur/X/X178 (2).jpg
#   inflating: dataset_R_G_blur/X/X178.jpg
#   inflating: dataset_R_G_blur/X/X179 (2).jpg
#   inflating: dataset_R_G_blur/X/X179.jpg
#   inflating: dataset_R_G_blur/X/X18 (2).jpg
#   inflating: dataset_R_G_blur/X/X18.jpg
#   inflating: dataset_R_G_blur/X/X180 (2).jpg
#   inflating: dataset_R_G_blur/X/X180.jpg
#   inflating: dataset_R_G_blur/X/X181 (2).jpg
#   inflating: dataset_R_G_blur/X/X181.jpg
#   inflating: dataset_R_G_blur/X/X182 (2).jpg
#   inflating: dataset_R_G_blur/X/X182.jpg
#   inflating: dataset_R_G_blur/X/X183 (2).jpg
#   inflating: dataset_R_G_blur/X/X183.jpg
#   inflating: dataset_R_G_blur/X/X184 (2).jpg
#   inflating: dataset_R_G_blur/X/X184.jpg
#   inflating: dataset_R_G_blur/X/X185 (2).jpg
#   inflating: dataset_R_G_blur/X/X185.jpg
#   inflating: dataset_R_G_blur/X/X186 (2).jpg
#   inflating: dataset_R_G_blur/X/X186.jpg
#   inflating: dataset_R_G_blur/X/X187 (2).jpg
#   inflating: dataset_R_G_blur/X/X187.jpg
#   inflating: dataset_R_G_blur/X/X188 (2).jpg
#   inflating: dataset_R_G_blur/X/X188.jpg
#   inflating: dataset_R_G_blur/X/X189 (2).jpg
#   inflating: dataset_R_G_blur/X/X189.jpg
#   inflating: dataset_R_G_blur/X/X19 (2).jpg
#   inflating: dataset_R_G_blur/X/X19.jpg
#   inflating: dataset_R_G_blur/X/X190 (2).jpg
#   inflating: dataset_R_G_blur/X/X190.jpg
#   inflating: dataset_R_G_blur/X/X191 (2).jpg
#   inflating: dataset_R_G_blur/X/X191.jpg
#   inflating: dataset_R_G_blur/X/X192 (2).jpg
#   inflating: dataset_R_G_blur/X/X192.jpg
#   inflating: dataset_R_G_blur/X/X193 (2).jpg
#   inflating: dataset_R_G_blur/X/X193.jpg
#   inflating: dataset_R_G_blur/X/X194 (2).jpg
#   inflating: dataset_R_G_blur/X/X194.jpg
#   inflating: dataset_R_G_blur/X/X195 (2).jpg
#   inflating: dataset_R_G_blur/X/X195.jpg
#   inflating: dataset_R_G_blur/X/X196 (2).jpg
#   inflating: dataset_R_G_blur/X/X196.jpg
#   inflating: dataset_R_G_blur/X/X197 (2).jpg
#   inflating: dataset_R_G_blur/X/X197.jpg
#   inflating: dataset_R_G_blur/X/X198 (2).jpg
#   inflating: dataset_R_G_blur/X/X198.jpg
#   inflating: dataset_R_G_blur/X/X199 (2).jpg
#   inflating: dataset_R_G_blur/X/X199.jpg
#   inflating: dataset_R_G_blur/X/X2 (2).jpg
#   inflating: dataset_R_G_blur/X/X2.jpg
#   inflating: dataset_R_G_blur/X/X20 (2).jpg
#   inflating: dataset_R_G_blur/X/X20.jpg
#   inflating: dataset_R_G_blur/X/X200 (2).jpg
#   inflating: dataset_R_G_blur/X/X200.jpg
#   inflating: dataset_R_G_blur/X/X201 (2).jpg
#   inflating: dataset_R_G_blur/X/X201.jpg
#   inflating: dataset_R_G_blur/X/X202 (2).jpg
#   inflating: dataset_R_G_blur/X/X202.jpg
#   inflating: dataset_R_G_blur/X/X203 (2).jpg
#   inflating: dataset_R_G_blur/X/X203.jpg
#   inflating: dataset_R_G_blur/X/X204 (2).jpg
#   inflating: dataset_R_G_blur/X/X204.jpg
#   inflating: dataset_R_G_blur/X/X205 (2).jpg
#   inflating: dataset_R_G_blur/X/X205.jpg
#   inflating: dataset_R_G_blur/X/X206 (2).jpg
#   inflating: dataset_R_G_blur/X/X206.jpg
#   inflating: dataset_R_G_blur/X/X207 (2).jpg
#   inflating: dataset_R_G_blur/X/X207.jpg
#   inflating: dataset_R_G_blur/X/X208 (2).jpg
#   inflating: dataset_R_G_blur/X/X208.jpg
#   inflating: dataset_R_G_blur/X/X209 (2).jpg
#   inflating: dataset_R_G_blur/X/X209.jpg
#   inflating: dataset_R_G_blur/X/X21 (2).jpg
#   inflating: dataset_R_G_blur/X/X21.jpg
#   inflating: dataset_R_G_blur/X/X210 (2).jpg
#   inflating: dataset_R_G_blur/X/X210.jpg
#   inflating: dataset_R_G_blur/X/X211 (2).jpg
#   inflating: dataset_R_G_blur/X/X211.jpg
#   inflating: dataset_R_G_blur/X/X212 (2).jpg
#   inflating: dataset_R_G_blur/X/X212.jpg
#   inflating: dataset_R_G_blur/X/X213 (2).jpg
#   inflating: dataset_R_G_blur/X/X213.jpg
#   inflating: dataset_R_G_blur/X/X214 (2).jpg
#   inflating: dataset_R_G_blur/X/X214.jpg
#   inflating: dataset_R_G_blur/X/X215 (2).jpg
#   inflating: dataset_R_G_blur/X/X215.jpg
#   inflating: dataset_R_G_blur/X/X216 (2).jpg
#   inflating: dataset_R_G_blur/X/X216.jpg
#   inflating: dataset_R_G_blur/X/X217 (2).jpg
#   inflating: dataset_R_G_blur/X/X217.jpg
#   inflating: dataset_R_G_blur/X/X218 (2).jpg
#   inflating: dataset_R_G_blur/X/X218.jpg
#   inflating: dataset_R_G_blur/X/X219 (2).jpg
#   inflating: dataset_R_G_blur/X/X219.jpg
#   inflating: dataset_R_G_blur/X/X22 (2).jpg
#   inflating: dataset_R_G_blur/X/X22.jpg
#   inflating: dataset_R_G_blur/X/X220 (2).jpg
#   inflating: dataset_R_G_blur/X/X220.jpg
#   inflating: dataset_R_G_blur/X/X221 (2).jpg
#   inflating: dataset_R_G_blur/X/X221.jpg
#   inflating: dataset_R_G_blur/X/X222 (2).jpg
#   inflating: dataset_R_G_blur/X/X222.jpg
#   inflating: dataset_R_G_blur/X/X223 (2).jpg
#   inflating: dataset_R_G_blur/X/X223.jpg
#   inflating: dataset_R_G_blur/X/X224 (2).jpg
#   inflating: dataset_R_G_blur/X/X224.jpg
#   inflating: dataset_R_G_blur/X/X225 (2).jpg
#   inflating: dataset_R_G_blur/X/X225.jpg
#   inflating: dataset_R_G_blur/X/X226 (2).jpg
#   inflating: dataset_R_G_blur/X/X226.jpg
#   inflating: dataset_R_G_blur/X/X227 (2).jpg
#   inflating: dataset_R_G_blur/X/X227.jpg
#   inflating: dataset_R_G_blur/X/X228 (2).jpg
#   inflating: dataset_R_G_blur/X/X228.jpg
#   inflating: dataset_R_G_blur/X/X229 (2).jpg
#   inflating: dataset_R_G_blur/X/X229.jpg
#   inflating: dataset_R_G_blur/X/X23 (2).jpg
#   inflating: dataset_R_G_blur/X/X23.jpg
#   inflating: dataset_R_G_blur/X/X230 (2).jpg
#   inflating: dataset_R_G_blur/X/X230.jpg
#   inflating: dataset_R_G_blur/X/X231 (2).jpg
#   inflating: dataset_R_G_blur/X/X231.jpg
#   inflating: dataset_R_G_blur/X/X232 (2).jpg
#   inflating: dataset_R_G_blur/X/X232.jpg
#   inflating: dataset_R_G_blur/X/X233 (2).jpg
#   inflating: dataset_R_G_blur/X/X233.jpg
#   inflating: dataset_R_G_blur/X/X234 (2).jpg
#   inflating: dataset_R_G_blur/X/X234.jpg
#   inflating: dataset_R_G_blur/X/X235 (2).jpg
#   inflating: dataset_R_G_blur/X/X235.jpg
#   inflating: dataset_R_G_blur/X/X236 (2).jpg
#   inflating: dataset_R_G_blur/X/X236.jpg
#   inflating: dataset_R_G_blur/X/X237 (2).jpg
#   inflating: dataset_R_G_blur/X/X237.jpg
#   inflating: dataset_R_G_blur/X/X238 (2).jpg
#   inflating: dataset_R_G_blur/X/X238.jpg
#   inflating: dataset_R_G_blur/X/X239 (2).jpg
#   inflating: dataset_R_G_blur/X/X239.jpg
#   inflating: dataset_R_G_blur/X/X24 (2).jpg
#   inflating: dataset_R_G_blur/X/X24.jpg
#   inflating: dataset_R_G_blur/X/X240 (2).jpg
#   inflating: dataset_R_G_blur/X/X240.jpg
#   inflating: dataset_R_G_blur/X/X241 (2).jpg
#   inflating: dataset_R_G_blur/X/X241.jpg
#   inflating: dataset_R_G_blur/X/X242 (2).jpg
#   inflating: dataset_R_G_blur/X/X242.jpg
#   inflating: dataset_R_G_blur/X/X243 (2).jpg
#   inflating: dataset_R_G_blur/X/X243.jpg
#   inflating: dataset_R_G_blur/X/X244 (2).jpg
#   inflating: dataset_R_G_blur/X/X244.jpg
#   inflating: dataset_R_G_blur/X/X245 (2).jpg
#   inflating: dataset_R_G_blur/X/X245.jpg
#   inflating: dataset_R_G_blur/X/X246 (2).jpg
#   inflating: dataset_R_G_blur/X/X246.jpg
#   inflating: dataset_R_G_blur/X/X247 (2).jpg
#   inflating: dataset_R_G_blur/X/X247.jpg
#   inflating: dataset_R_G_blur/X/X248 (2).jpg
#   inflating: dataset_R_G_blur/X/X248.jpg
#   inflating: dataset_R_G_blur/X/X249 (2).jpg
#   inflating: dataset_R_G_blur/X/X249.jpg
#   inflating: dataset_R_G_blur/X/X25 (2).jpg
#   inflating: dataset_R_G_blur/X/X25.jpg
#   inflating: dataset_R_G_blur/X/X250 (2).jpg
#   inflating: dataset_R_G_blur/X/X250.jpg
#   inflating: dataset_R_G_blur/X/X251 (2).jpg
#   inflating: dataset_R_G_blur/X/X251.jpg
#   inflating: dataset_R_G_blur/X/X252 (2).jpg
#   inflating: dataset_R_G_blur/X/X252.jpg
#   inflating: dataset_R_G_blur/X/X253 (2).jpg
#   inflating: dataset_R_G_blur/X/X253.jpg
#   inflating: dataset_R_G_blur/X/X254 (2).jpg
#   inflating: dataset_R_G_blur/X/X254.jpg
#   inflating: dataset_R_G_blur/X/X255 (2).jpg
#   inflating: dataset_R_G_blur/X/X255.jpg
#   inflating: dataset_R_G_blur/X/X256 (2).jpg
#   inflating: dataset_R_G_blur/X/X256.jpg
#   inflating: dataset_R_G_blur/X/X257 (2).jpg
#   inflating: dataset_R_G_blur/X/X257.jpg
#   inflating: dataset_R_G_blur/X/X258 (2).jpg
#   inflating: dataset_R_G_blur/X/X258.jpg
#   inflating: dataset_R_G_blur/X/X259 (2).jpg
#   inflating: dataset_R_G_blur/X/X259.jpg
#   inflating: dataset_R_G_blur/X/X26 (2).jpg
#   inflating: dataset_R_G_blur/X/X26.jpg
#   inflating: dataset_R_G_blur/X/X260 (2).jpg
#   inflating: dataset_R_G_blur/X/X260.jpg
#   inflating: dataset_R_G_blur/X/X261 (2).jpg
#   inflating: dataset_R_G_blur/X/X261.jpg
#   inflating: dataset_R_G_blur/X/X262 (2).jpg
#   inflating: dataset_R_G_blur/X/X262.jpg
#   inflating: dataset_R_G_blur/X/X263 (2).jpg
#   inflating: dataset_R_G_blur/X/X263.jpg
#   inflating: dataset_R_G_blur/X/X264 (2).jpg
#   inflating: dataset_R_G_blur/X/X264.jpg
#   inflating: dataset_R_G_blur/X/X265 (2).jpg
#   inflating: dataset_R_G_blur/X/X265.jpg
#   inflating: dataset_R_G_blur/X/X266 (2).jpg
#   inflating: dataset_R_G_blur/X/X266.jpg
#   inflating: dataset_R_G_blur/X/X267 (2).jpg
#   inflating: dataset_R_G_blur/X/X267.jpg
#   inflating: dataset_R_G_blur/X/X268 (2).jpg
#   inflating: dataset_R_G_blur/X/X268.jpg
#   inflating: dataset_R_G_blur/X/X269 (2).jpg
#   inflating: dataset_R_G_blur/X/X269.jpg
#   inflating: dataset_R_G_blur/X/X27 (2).jpg
#   inflating: dataset_R_G_blur/X/X27.jpg
#   inflating: dataset_R_G_blur/X/X270 (2).jpg
#   inflating: dataset_R_G_blur/X/X270.jpg
#   inflating: dataset_R_G_blur/X/X271 (2).jpg
#   inflating: dataset_R_G_blur/X/X271.jpg
#   inflating: dataset_R_G_blur/X/X272 (2).jpg
#   inflating: dataset_R_G_blur/X/X272.jpg
#   inflating: dataset_R_G_blur/X/X273 (2).jpg
#   inflating: dataset_R_G_blur/X/X273.jpg
#   inflating: dataset_R_G_blur/X/X274 (2).jpg
#   inflating: dataset_R_G_blur/X/X274.jpg
#   inflating: dataset_R_G_blur/X/X275 (2).jpg
#   inflating: dataset_R_G_blur/X/X275.jpg
#   inflating: dataset_R_G_blur/X/X276 (2).jpg
#   inflating: dataset_R_G_blur/X/X276.jpg
#   inflating: dataset_R_G_blur/X/X277 (2).jpg
#   inflating: dataset_R_G_blur/X/X277.jpg
#   inflating: dataset_R_G_blur/X/X278 (2).jpg
#   inflating: dataset_R_G_blur/X/X278.jpg
#   inflating: dataset_R_G_blur/X/X279 (2).jpg
#   inflating: dataset_R_G_blur/X/X279.jpg
#   inflating: dataset_R_G_blur/X/X28 (2).jpg
#   inflating: dataset_R_G_blur/X/X28.jpg
#   inflating: dataset_R_G_blur/X/X280 (2).jpg
#   inflating: dataset_R_G_blur/X/X280.jpg
#   inflating: dataset_R_G_blur/X/X281 (2).jpg
#   inflating: dataset_R_G_blur/X/X281.jpg
#   inflating: dataset_R_G_blur/X/X282 (2).jpg
#   inflating: dataset_R_G_blur/X/X282.jpg
#   inflating: dataset_R_G_blur/X/X283 (2).jpg
#   inflating: dataset_R_G_blur/X/X283.jpg
#   inflating: dataset_R_G_blur/X/X284 (2).jpg
#   inflating: dataset_R_G_blur/X/X284.jpg
#   inflating: dataset_R_G_blur/X/X285 (2).jpg
#   inflating: dataset_R_G_blur/X/X285.jpg
#   inflating: dataset_R_G_blur/X/X286 (2).jpg
#   inflating: dataset_R_G_blur/X/X286.jpg
#   inflating: dataset_R_G_blur/X/X287 (2).jpg
#   inflating: dataset_R_G_blur/X/X287.jpg
#   inflating: dataset_R_G_blur/X/X288 (2).jpg
#   inflating: dataset_R_G_blur/X/X288.jpg
#   inflating: dataset_R_G_blur/X/X289 (2).jpg
#   inflating: dataset_R_G_blur/X/X289.jpg
#   inflating: dataset_R_G_blur/X/X29 (2).jpg
#   inflating: dataset_R_G_blur/X/X29.jpg
#   inflating: dataset_R_G_blur/X/X290 (2).jpg
#   inflating: dataset_R_G_blur/X/X290.jpg
#   inflating: dataset_R_G_blur/X/X291 (2).jpg
#   inflating: dataset_R_G_blur/X/X291.jpg
#   inflating: dataset_R_G_blur/X/X292 (2).jpg
#   inflating: dataset_R_G_blur/X/X292.jpg
#   inflating: dataset_R_G_blur/X/X293 (2).jpg
#   inflating: dataset_R_G_blur/X/X293.jpg
#   inflating: dataset_R_G_blur/X/X294 (2).jpg
#   inflating: dataset_R_G_blur/X/X294.jpg
#   inflating: dataset_R_G_blur/X/X295 (2).jpg
#   inflating: dataset_R_G_blur/X/X295.jpg
#   inflating: dataset_R_G_blur/X/X296 (2).jpg
#   inflating: dataset_R_G_blur/X/X296.jpg
#   inflating: dataset_R_G_blur/X/X297 (2).jpg
#   inflating: dataset_R_G_blur/X/X297.jpg
#   inflating: dataset_R_G_blur/X/X298 (2).jpg
#   inflating: dataset_R_G_blur/X/X298.jpg
#   inflating: dataset_R_G_blur/X/X299 (2).jpg
#   inflating: dataset_R_G_blur/X/X299.jpg
#   inflating: dataset_R_G_blur/X/X3 (2).jpg
#   inflating: dataset_R_G_blur/X/X3.jpg
#   inflating: dataset_R_G_blur/X/X30 (2).jpg
#   inflating: dataset_R_G_blur/X/X30.jpg
#   inflating: dataset_R_G_blur/X/X300 (2).jpg
#   inflating: dataset_R_G_blur/X/X300.jpg
#   inflating: dataset_R_G_blur/X/X301.jpg
#   inflating: dataset_R_G_blur/X/X302.jpg
#   inflating: dataset_R_G_blur/X/X303.jpg
#   inflating: dataset_R_G_blur/X/X304.jpg
#   inflating: dataset_R_G_blur/X/X305.jpg
#   inflating: dataset_R_G_blur/X/X306.jpg
#   inflating: dataset_R_G_blur/X/X307.jpg
#   inflating: dataset_R_G_blur/X/X308.jpg
#   inflating: dataset_R_G_blur/X/X309.jpg
#   inflating: dataset_R_G_blur/X/X31 (2).jpg
#   inflating: dataset_R_G_blur/X/X31.jpg
#   inflating: dataset_R_G_blur/X/X310.jpg
#   inflating: dataset_R_G_blur/X/X311.jpg
#   inflating: dataset_R_G_blur/X/X312.jpg
#   inflating: dataset_R_G_blur/X/X313.jpg
#   inflating: dataset_R_G_blur/X/X314.jpg
#   inflating: dataset_R_G_blur/X/X315.jpg
#   inflating: dataset_R_G_blur/X/X316.jpg
#   inflating: dataset_R_G_blur/X/X317.jpg
#   inflating: dataset_R_G_blur/X/X318.jpg
#   inflating: dataset_R_G_blur/X/X319.jpg
#   inflating: dataset_R_G_blur/X/X32 (2).jpg
#   inflating: dataset_R_G_blur/X/X32.jpg
#   inflating: dataset_R_G_blur/X/X320.jpg
#   inflating: dataset_R_G_blur/X/X321.jpg
#   inflating: dataset_R_G_blur/X/X322.jpg
#   inflating: dataset_R_G_blur/X/X323.jpg
#   inflating: dataset_R_G_blur/X/X324.jpg
#   inflating: dataset_R_G_blur/X/X325.jpg
#   inflating: dataset_R_G_blur/X/X326.jpg
#   inflating: dataset_R_G_blur/X/X327.jpg
#   inflating: dataset_R_G_blur/X/X328.jpg
#   inflating: dataset_R_G_blur/X/X329.jpg
#   inflating: dataset_R_G_blur/X/X33 (2).jpg
#   inflating: dataset_R_G_blur/X/X33.jpg
#   inflating: dataset_R_G_blur/X/X330.jpg
#   inflating: dataset_R_G_blur/X/X331.jpg
#   inflating: dataset_R_G_blur/X/X332.jpg
#   inflating: dataset_R_G_blur/X/X333.jpg
#   inflating: dataset_R_G_blur/X/X334.jpg
#   inflating: dataset_R_G_blur/X/X335.jpg
#   inflating: dataset_R_G_blur/X/X336.jpg
#   inflating: dataset_R_G_blur/X/X337.jpg
#   inflating: dataset_R_G_blur/X/X338.jpg
#   inflating: dataset_R_G_blur/X/X339.jpg
#   inflating: dataset_R_G_blur/X/X34 (2).jpg
#   inflating: dataset_R_G_blur/X/X34.jpg
#   inflating: dataset_R_G_blur/X/X340.jpg
#   inflating: dataset_R_G_blur/X/X341.jpg
#   inflating: dataset_R_G_blur/X/X342.jpg
#   inflating: dataset_R_G_blur/X/X343.jpg
#   inflating: dataset_R_G_blur/X/X344.jpg
#   inflating: dataset_R_G_blur/X/X345.jpg
#   inflating: dataset_R_G_blur/X/X346.jpg
#   inflating: dataset_R_G_blur/X/X347.jpg
#   inflating: dataset_R_G_blur/X/X348.jpg
#   inflating: dataset_R_G_blur/X/X349.jpg
#   inflating: dataset_R_G_blur/X/X35 (2).jpg
#   inflating: dataset_R_G_blur/X/X35.jpg
#   inflating: dataset_R_G_blur/X/X350.jpg
#   inflating: dataset_R_G_blur/X/X351.jpg
#   inflating: dataset_R_G_blur/X/X352.jpg
#   inflating: dataset_R_G_blur/X/X353.jpg
#   inflating: dataset_R_G_blur/X/X354.jpg
#   inflating: dataset_R_G_blur/X/X355.jpg
#   inflating: dataset_R_G_blur/X/X356.jpg
#   inflating: dataset_R_G_blur/X/X357.jpg
#   inflating: dataset_R_G_blur/X/X358.jpg
#   inflating: dataset_R_G_blur/X/X359.jpg
#   inflating: dataset_R_G_blur/X/X36 (2).jpg
#   inflating: dataset_R_G_blur/X/X36.jpg
#   inflating: dataset_R_G_blur/X/X360.jpg
#   inflating: dataset_R_G_blur/X/X361.jpg
#   inflating: dataset_R_G_blur/X/X362.jpg
#   inflating: dataset_R_G_blur/X/X363.jpg
#   inflating: dataset_R_G_blur/X/X364.jpg
#   inflating: dataset_R_G_blur/X/X365.jpg
#   inflating: dataset_R_G_blur/X/X366.jpg
#   inflating: dataset_R_G_blur/X/X367.jpg
#   inflating: dataset_R_G_blur/X/X368.jpg
#   inflating: dataset_R_G_blur/X/X369.jpg
#   inflating: dataset_R_G_blur/X/X37 (2).jpg
#   inflating: dataset_R_G_blur/X/X37.jpg
#   inflating: dataset_R_G_blur/X/X370.jpg
#   inflating: dataset_R_G_blur/X/X371.jpg
#   inflating: dataset_R_G_blur/X/X372.jpg
#   inflating: dataset_R_G_blur/X/X373.jpg
#   inflating: dataset_R_G_blur/X/X374.jpg
#   inflating: dataset_R_G_blur/X/X375.jpg
#   inflating: dataset_R_G_blur/X/X376.jpg
#   inflating: dataset_R_G_blur/X/X377.jpg
#   inflating: dataset_R_G_blur/X/X378.jpg
#   inflating: dataset_R_G_blur/X/X379.jpg
#   inflating: dataset_R_G_blur/X/X38 (2).jpg
#   inflating: dataset_R_G_blur/X/X38.jpg
#   inflating: dataset_R_G_blur/X/X380.jpg
#   inflating: dataset_R_G_blur/X/X381.jpg
#   inflating: dataset_R_G_blur/X/X382.jpg
#   inflating: dataset_R_G_blur/X/X383.jpg
#   inflating: dataset_R_G_blur/X/X384.jpg
#   inflating: dataset_R_G_blur/X/X385.jpg
#   inflating: dataset_R_G_blur/X/X386.jpg
#   inflating: dataset_R_G_blur/X/X387.jpg
#   inflating: dataset_R_G_blur/X/X388.jpg
#   inflating: dataset_R_G_blur/X/X389.jpg
#   inflating: dataset_R_G_blur/X/X39 (2).jpg
#   inflating: dataset_R_G_blur/X/X39.jpg
#   inflating: dataset_R_G_blur/X/X390.jpg
#   inflating: dataset_R_G_blur/X/X391.jpg
#   inflating: dataset_R_G_blur/X/X392.jpg
#   inflating: dataset_R_G_blur/X/X393.jpg
#   inflating: dataset_R_G_blur/X/X394.jpg
#   inflating: dataset_R_G_blur/X/X395.jpg
#   inflating: dataset_R_G_blur/X/X396.jpg
#   inflating: dataset_R_G_blur/X/X397.jpg
#   inflating: dataset_R_G_blur/X/X398.jpg
#   inflating: dataset_R_G_blur/X/X399.jpg
#   inflating: dataset_R_G_blur/X/X4 (2).jpg
#   inflating: dataset_R_G_blur/X/X4.jpg
#   inflating: dataset_R_G_blur/X/X40 (2).jpg
#   inflating: dataset_R_G_blur/X/X40.jpg
#   inflating: dataset_R_G_blur/X/X400.jpg
#   inflating: dataset_R_G_blur/X/X401.jpg
#   inflating: dataset_R_G_blur/X/X402.jpg
#   inflating: dataset_R_G_blur/X/X403.jpg
#   inflating: dataset_R_G_blur/X/X404.jpg
#   inflating: dataset_R_G_blur/X/X405.jpg
#   inflating: dataset_R_G_blur/X/X406.jpg
#   inflating: dataset_R_G_blur/X/X407.jpg
#   inflating: dataset_R_G_blur/X/X408.jpg
#   inflating: dataset_R_G_blur/X/X409.jpg
#   inflating: dataset_R_G_blur/X/X41 (2).jpg
#   inflating: dataset_R_G_blur/X/X41.jpg
#   inflating: dataset_R_G_blur/X/X410.jpg
#   inflating: dataset_R_G_blur/X/X411.jpg
#   inflating: dataset_R_G_blur/X/X412.jpg
#   inflating: dataset_R_G_blur/X/X413.jpg
#   inflating: dataset_R_G_blur/X/X414.jpg
#   inflating: dataset_R_G_blur/X/X415.jpg
#   inflating: dataset_R_G_blur/X/X416.jpg
#   inflating: dataset_R_G_blur/X/X417.jpg
#   inflating: dataset_R_G_blur/X/X418.jpg
#   inflating: dataset_R_G_blur/X/X419.jpg
#   inflating: dataset_R_G_blur/X/X42 (2).jpg
#   inflating: dataset_R_G_blur/X/X42.jpg
#   inflating: dataset_R_G_blur/X/X420.jpg
#   inflating: dataset_R_G_blur/X/X421.jpg
#   inflating: dataset_R_G_blur/X/X422.jpg
#   inflating: dataset_R_G_blur/X/X423.jpg
#   inflating: dataset_R_G_blur/X/X424.jpg
#   inflating: dataset_R_G_blur/X/X425.jpg
#   inflating: dataset_R_G_blur/X/X426.jpg
#   inflating: dataset_R_G_blur/X/X427.jpg
#   inflating: dataset_R_G_blur/X/X428.jpg
#   inflating: dataset_R_G_blur/X/X429.jpg
#   inflating: dataset_R_G_blur/X/X43 (2).jpg
#   inflating: dataset_R_G_blur/X/X43.jpg
#   inflating: dataset_R_G_blur/X/X430.jpg
#   inflating: dataset_R_G_blur/X/X431.jpg
#   inflating: dataset_R_G_blur/X/X432.jpg
#   inflating: dataset_R_G_blur/X/X433.jpg
#   inflating: dataset_R_G_blur/X/X434.jpg
#   inflating: dataset_R_G_blur/X/X435.jpg
#   inflating: dataset_R_G_blur/X/X436.jpg
#   inflating: dataset_R_G_blur/X/X437.jpg
#   inflating: dataset_R_G_blur/X/X438.jpg
#   inflating: dataset_R_G_blur/X/X439.jpg
#   inflating: dataset_R_G_blur/X/X44 (2).jpg
#   inflating: dataset_R_G_blur/X/X44.jpg
#   inflating: dataset_R_G_blur/X/X440.jpg
#   inflating: dataset_R_G_blur/X/X441.jpg
#   inflating: dataset_R_G_blur/X/X442.jpg
#   inflating: dataset_R_G_blur/X/X443.jpg
#   inflating: dataset_R_G_blur/X/X444.jpg
#   inflating: dataset_R_G_blur/X/X445.jpg
#   inflating: dataset_R_G_blur/X/X446.jpg
#   inflating: dataset_R_G_blur/X/X447.jpg
#   inflating: dataset_R_G_blur/X/X448.jpg
#   inflating: dataset_R_G_blur/X/X449.jpg
#   inflating: dataset_R_G_blur/X/X45 (2).jpg
#   inflating: dataset_R_G_blur/X/X45.jpg
#   inflating: dataset_R_G_blur/X/X450.jpg
#   inflating: dataset_R_G_blur/X/X451.jpg
#   inflating: dataset_R_G_blur/X/X452.jpg
#   inflating: dataset_R_G_blur/X/X453.jpg
#   inflating: dataset_R_G_blur/X/X454.jpg
#   inflating: dataset_R_G_blur/X/X455.jpg
#   inflating: dataset_R_G_blur/X/X456.jpg
#   inflating: dataset_R_G_blur/X/X457.jpg
#   inflating: dataset_R_G_blur/X/X458.jpg
#   inflating: dataset_R_G_blur/X/X459.jpg
#   inflating: dataset_R_G_blur/X/X46 (2).jpg
#   inflating: dataset_R_G_blur/X/X46.jpg
#   inflating: dataset_R_G_blur/X/X460.jpg
#   inflating: dataset_R_G_blur/X/X461.jpg
#   inflating: dataset_R_G_blur/X/X462.jpg
#   inflating: dataset_R_G_blur/X/X463.jpg
#   inflating: dataset_R_G_blur/X/X464.jpg
#   inflating: dataset_R_G_blur/X/X465.jpg
#   inflating: dataset_R_G_blur/X/X466.jpg
#   inflating: dataset_R_G_blur/X/X467.jpg
#   inflating: dataset_R_G_blur/X/X468.jpg
#   inflating: dataset_R_G_blur/X/X469.jpg
#   inflating: dataset_R_G_blur/X/X47 (2).jpg
#   inflating: dataset_R_G_blur/X/X47.jpg
#   inflating: dataset_R_G_blur/X/X470.jpg
#   inflating: dataset_R_G_blur/X/X471.jpg
#   inflating: dataset_R_G_blur/X/X472.jpg
#   inflating: dataset_R_G_blur/X/X473.jpg
#   inflating: dataset_R_G_blur/X/X474.jpg
#   inflating: dataset_R_G_blur/X/X475.jpg
#   inflating: dataset_R_G_blur/X/X476.jpg
#   inflating: dataset_R_G_blur/X/X477.jpg
#   inflating: dataset_R_G_blur/X/X478.jpg
#   inflating: dataset_R_G_blur/X/X479.jpg
#   inflating: dataset_R_G_blur/X/X48 (2).jpg
#   inflating: dataset_R_G_blur/X/X48.jpg
#   inflating: dataset_R_G_blur/X/X480.jpg
#   inflating: dataset_R_G_blur/X/X481.jpg
#   inflating: dataset_R_G_blur/X/X482.jpg
#   inflating: dataset_R_G_blur/X/X483.jpg
#   inflating: dataset_R_G_blur/X/X484.jpg
#   inflating: dataset_R_G_blur/X/X485.jpg
#   inflating: dataset_R_G_blur/X/X486.jpg
#   inflating: dataset_R_G_blur/X/X487.jpg
#   inflating: dataset_R_G_blur/X/X488.jpg
#   inflating: dataset_R_G_blur/X/X489.jpg
#   inflating: dataset_R_G_blur/X/X49 (2).jpg
#   inflating: dataset_R_G_blur/X/X49.jpg
#   inflating: dataset_R_G_blur/X/X490.jpg
#   inflating: dataset_R_G_blur/X/X491.jpg
#   inflating: dataset_R_G_blur/X/X492.jpg
#   inflating: dataset_R_G_blur/X/X493.jpg
#   inflating: dataset_R_G_blur/X/X494.jpg
#   inflating: dataset_R_G_blur/X/X495.jpg
#   inflating: dataset_R_G_blur/X/X496.jpg
#   inflating: dataset_R_G_blur/X/X497.jpg
#   inflating: dataset_R_G_blur/X/X498.jpg
#   inflating: dataset_R_G_blur/X/X499.jpg
#   inflating: dataset_R_G_blur/X/X5 (2).jpg
#   inflating: dataset_R_G_blur/X/X5.jpg
#   inflating: dataset_R_G_blur/X/X50 (2).jpg
#   inflating: dataset_R_G_blur/X/X50.jpg
#   inflating: dataset_R_G_blur/X/X500.jpg
#   inflating: dataset_R_G_blur/X/X501.jpg
#   inflating: dataset_R_G_blur/X/X502.jpg
#   inflating: dataset_R_G_blur/X/X503.jpg
#   inflating: dataset_R_G_blur/X/X504.jpg
#   inflating: dataset_R_G_blur/X/X505.jpg
#   inflating: dataset_R_G_blur/X/X506.jpg
#   inflating: dataset_R_G_blur/X/X507.jpg
#   inflating: dataset_R_G_blur/X/X508.jpg
#   inflating: dataset_R_G_blur/X/X509.jpg
#   inflating: dataset_R_G_blur/X/X51 (2).jpg
#   inflating: dataset_R_G_blur/X/X51.jpg
#   inflating: dataset_R_G_blur/X/X510.jpg
#   inflating: dataset_R_G_blur/X/X511.jpg
#   inflating: dataset_R_G_blur/X/X512.jpg
#   inflating: dataset_R_G_blur/X/X513.jpg
#   inflating: dataset_R_G_blur/X/X514.jpg
#   inflating: dataset_R_G_blur/X/X515.jpg
#   inflating: dataset_R_G_blur/X/X516.jpg
#   inflating: dataset_R_G_blur/X/X517.jpg
#   inflating: dataset_R_G_blur/X/X518.jpg
#   inflating: dataset_R_G_blur/X/X519.jpg
#   inflating: dataset_R_G_blur/X/X52 (2).jpg
#   inflating: dataset_R_G_blur/X/X52.jpg
#   inflating: dataset_R_G_blur/X/X520.jpg
#   inflating: dataset_R_G_blur/X/X521.jpg
#   inflating: dataset_R_G_blur/X/X522.jpg
#   inflating: dataset_R_G_blur/X/X523.jpg
#   inflating: dataset_R_G_blur/X/X524.jpg
#   inflating: dataset_R_G_blur/X/X525.jpg
#   inflating: dataset_R_G_blur/X/X526.jpg
#   inflating: dataset_R_G_blur/X/X527.jpg
#   inflating: dataset_R_G_blur/X/X528.jpg
#   inflating: dataset_R_G_blur/X/X529.jpg
#   inflating: dataset_R_G_blur/X/X53 (2).jpg
#   inflating: dataset_R_G_blur/X/X53.jpg
#   inflating: dataset_R_G_blur/X/X530.jpg
#   inflating: dataset_R_G_blur/X/X531.jpg
#   inflating: dataset_R_G_blur/X/X532.jpg
#   inflating: dataset_R_G_blur/X/X533.jpg
#   inflating: dataset_R_G_blur/X/X534.jpg
#   inflating: dataset_R_G_blur/X/X535.jpg
#   inflating: dataset_R_G_blur/X/X536.jpg
#   inflating: dataset_R_G_blur/X/X537.jpg
#   inflating: dataset_R_G_blur/X/X538.jpg
#   inflating: dataset_R_G_blur/X/X539.jpg
#   inflating: dataset_R_G_blur/X/X54 (2).jpg
#   inflating: dataset_R_G_blur/X/X54.jpg
#   inflating: dataset_R_G_blur/X/X540.jpg
#   inflating: dataset_R_G_blur/X/X541.jpg
#   inflating: dataset_R_G_blur/X/X542.jpg
#   inflating: dataset_R_G_blur/X/X543.jpg
#   inflating: dataset_R_G_blur/X/X544.jpg
#   inflating: dataset_R_G_blur/X/X545.jpg
#   inflating: dataset_R_G_blur/X/X546.jpg
#   inflating: dataset_R_G_blur/X/X547.jpg
#   inflating: dataset_R_G_blur/X/X548.jpg
#   inflating: dataset_R_G_blur/X/X549.jpg
#   inflating: dataset_R_G_blur/X/X55 (2).jpg
#   inflating: dataset_R_G_blur/X/X55.jpg
#   inflating: dataset_R_G_blur/X/X550.jpg
#   inflating: dataset_R_G_blur/X/X551.jpg
#   inflating: dataset_R_G_blur/X/X552.jpg
#   inflating: dataset_R_G_blur/X/X553.jpg
#   inflating: dataset_R_G_blur/X/X554.jpg
#   inflating: dataset_R_G_blur/X/X555.jpg
#   inflating: dataset_R_G_blur/X/X556.jpg
#   inflating: dataset_R_G_blur/X/X557.jpg
#   inflating: dataset_R_G_blur/X/X558.jpg
#   inflating: dataset_R_G_blur/X/X559.jpg
#   inflating: dataset_R_G_blur/X/X56 (2).jpg
#   inflating: dataset_R_G_blur/X/X56.jpg
#   inflating: dataset_R_G_blur/X/X560.jpg
#   inflating: dataset_R_G_blur/X/X561.jpg
#   inflating: dataset_R_G_blur/X/X562.jpg
#   inflating: dataset_R_G_blur/X/X563.jpg
#   inflating: dataset_R_G_blur/X/X564.jpg
#   inflating: dataset_R_G_blur/X/X565.jpg
#   inflating: dataset_R_G_blur/X/X566.jpg
#   inflating: dataset_R_G_blur/X/X567.jpg
#   inflating: dataset_R_G_blur/X/X568.jpg
#   inflating: dataset_R_G_blur/X/X569.jpg
#   inflating: dataset_R_G_blur/X/X57 (2).jpg
#   inflating: dataset_R_G_blur/X/X57.jpg
#   inflating: dataset_R_G_blur/X/X570.jpg
#   inflating: dataset_R_G_blur/X/X571.jpg
#   inflating: dataset_R_G_blur/X/X572.jpg
#   inflating: dataset_R_G_blur/X/X573.jpg
#   inflating: dataset_R_G_blur/X/X574.jpg
#   inflating: dataset_R_G_blur/X/X575.jpg
#   inflating: dataset_R_G_blur/X/X576.jpg
#   inflating: dataset_R_G_blur/X/X577.jpg
#   inflating: dataset_R_G_blur/X/X578.jpg
#   inflating: dataset_R_G_blur/X/X579.jpg
#   inflating: dataset_R_G_blur/X/X58 (2).jpg
#   inflating: dataset_R_G_blur/X/X58.jpg
#   inflating: dataset_R_G_blur/X/X580.jpg
#   inflating: dataset_R_G_blur/X/X581.jpg
#   inflating: dataset_R_G_blur/X/X582.jpg
#   inflating: dataset_R_G_blur/X/X583.jpg
#   inflating: dataset_R_G_blur/X/X584.jpg
#   inflating: dataset_R_G_blur/X/X585.jpg
#   inflating: dataset_R_G_blur/X/X586.jpg
#   inflating: dataset_R_G_blur/X/X587.jpg
#   inflating: dataset_R_G_blur/X/X588.jpg
#   inflating: dataset_R_G_blur/X/X589.jpg
#   inflating: dataset_R_G_blur/X/X59 (2).jpg
#   inflating: dataset_R_G_blur/X/X59.jpg
#   inflating: dataset_R_G_blur/X/X590.jpg
#   inflating: dataset_R_G_blur/X/X591.jpg
#   inflating: dataset_R_G_blur/X/X592.jpg
#   inflating: dataset_R_G_blur/X/X593.jpg
#   inflating: dataset_R_G_blur/X/X594.jpg
#   inflating: dataset_R_G_blur/X/X595.jpg
#   inflating: dataset_R_G_blur/X/X596.jpg
#   inflating: dataset_R_G_blur/X/X597.jpg
#   inflating: dataset_R_G_blur/X/X598.jpg
#   inflating: dataset_R_G_blur/X/X599.jpg
#   inflating: dataset_R_G_blur/X/X6 (2).jpg
#   inflating: dataset_R_G_blur/X/X6.jpg
#   inflating: dataset_R_G_blur/X/X60 (2).jpg
#   inflating: dataset_R_G_blur/X/X60.jpg
#   inflating: dataset_R_G_blur/X/X600.jpg
#   inflating: dataset_R_G_blur/X/X601.jpg
#   inflating: dataset_R_G_blur/X/X602.jpg
#   inflating: dataset_R_G_blur/X/X603.jpg
#   inflating: dataset_R_G_blur/X/X604.jpg
#   inflating: dataset_R_G_blur/X/X605.jpg
#   inflating: dataset_R_G_blur/X/X606.jpg
#   inflating: dataset_R_G_blur/X/X607.jpg
#   inflating: dataset_R_G_blur/X/X608.jpg
#   inflating: dataset_R_G_blur/X/X609.jpg
#   inflating: dataset_R_G_blur/X/X61 (2).jpg
#   inflating: dataset_R_G_blur/X/X61.jpg
#   inflating: dataset_R_G_blur/X/X610.jpg
#   inflating: dataset_R_G_blur/X/X611.jpg
#   inflating: dataset_R_G_blur/X/X612.jpg
#   inflating: dataset_R_G_blur/X/X613.jpg
#   inflating: dataset_R_G_blur/X/X614.jpg
#   inflating: dataset_R_G_blur/X/X615.jpg
#   inflating: dataset_R_G_blur/X/X616.jpg
#   inflating: dataset_R_G_blur/X/X617.jpg
#   inflating: dataset_R_G_blur/X/X618.jpg
#   inflating: dataset_R_G_blur/X/X619.jpg
#   inflating: dataset_R_G_blur/X/X62 (2).jpg
#   inflating: dataset_R_G_blur/X/X62.jpg
#   inflating: dataset_R_G_blur/X/X620.jpg
#   inflating: dataset_R_G_blur/X/X621.jpg
#   inflating: dataset_R_G_blur/X/X622.jpg
#   inflating: dataset_R_G_blur/X/X623.jpg
#   inflating: dataset_R_G_blur/X/X624.jpg
#   inflating: dataset_R_G_blur/X/X625.jpg
#   inflating: dataset_R_G_blur/X/X626.jpg
#   inflating: dataset_R_G_blur/X/X627.jpg
#   inflating: dataset_R_G_blur/X/X628.jpg
#   inflating: dataset_R_G_blur/X/X629.jpg
#   inflating: dataset_R_G_blur/X/X63 (2).jpg
#   inflating: dataset_R_G_blur/X/X63.jpg
#   inflating: dataset_R_G_blur/X/X630.jpg
#   inflating: dataset_R_G_blur/X/X631.jpg
#   inflating: dataset_R_G_blur/X/X632.jpg
#   inflating: dataset_R_G_blur/X/X633.jpg
#   inflating: dataset_R_G_blur/X/X634.jpg
#   inflating: dataset_R_G_blur/X/X635.jpg
#   inflating: dataset_R_G_blur/X/X636.jpg
#   inflating: dataset_R_G_blur/X/X637.jpg
#   inflating: dataset_R_G_blur/X/X638.jpg
#   inflating: dataset_R_G_blur/X/X639.jpg
#   inflating: dataset_R_G_blur/X/X64 (2).jpg
#   inflating: dataset_R_G_blur/X/X64.jpg
#   inflating: dataset_R_G_blur/X/X640.jpg
#   inflating: dataset_R_G_blur/X/X641.jpg
#   inflating: dataset_R_G_blur/X/X642.jpg
#   inflating: dataset_R_G_blur/X/X643.jpg
#   inflating: dataset_R_G_blur/X/X644.jpg
#   inflating: dataset_R_G_blur/X/X645.jpg
#   inflating: dataset_R_G_blur/X/X646.jpg
#   inflating: dataset_R_G_blur/X/X647.jpg
#   inflating: dataset_R_G_blur/X/X648.jpg
#   inflating: dataset_R_G_blur/X/X649.jpg
#   inflating: dataset_R_G_blur/X/X65 (2).jpg
#   inflating: dataset_R_G_blur/X/X65.jpg
#   inflating: dataset_R_G_blur/X/X650.jpg
#   inflating: dataset_R_G_blur/X/X651.jpg
#   inflating: dataset_R_G_blur/X/X652.jpg
#   inflating: dataset_R_G_blur/X/X653.jpg
#   inflating: dataset_R_G_blur/X/X654.jpg
#   inflating: dataset_R_G_blur/X/X655.jpg
#   inflating: dataset_R_G_blur/X/X656.jpg
#   inflating: dataset_R_G_blur/X/X657.jpg
#   inflating: dataset_R_G_blur/X/X658.jpg
#   inflating: dataset_R_G_blur/X/X659.jpg
#   inflating: dataset_R_G_blur/X/X66 (2).jpg
#   inflating: dataset_R_G_blur/X/X66.jpg
#   inflating: dataset_R_G_blur/X/X660.jpg
#   inflating: dataset_R_G_blur/X/X661.jpg
#   inflating: dataset_R_G_blur/X/X662.jpg
#   inflating: dataset_R_G_blur/X/X663.jpg
#   inflating: dataset_R_G_blur/X/X664.jpg
#   inflating: dataset_R_G_blur/X/X665.jpg
#   inflating: dataset_R_G_blur/X/X666.jpg
#   inflating: dataset_R_G_blur/X/X667.jpg
#   inflating: dataset_R_G_blur/X/X668.jpg
#   inflating: dataset_R_G_blur/X/X669.jpg
#   inflating: dataset_R_G_blur/X/X67 (2).jpg
#   inflating: dataset_R_G_blur/X/X67.jpg
#   inflating: dataset_R_G_blur/X/X670.jpg
#   inflating: dataset_R_G_blur/X/X671.jpg
#   inflating: dataset_R_G_blur/X/X672.jpg
#   inflating: dataset_R_G_blur/X/X673.jpg
#   inflating: dataset_R_G_blur/X/X674.jpg
#   inflating: dataset_R_G_blur/X/X675.jpg
#   inflating: dataset_R_G_blur/X/X676.jpg
#   inflating: dataset_R_G_blur/X/X677.jpg
#   inflating: dataset_R_G_blur/X/X678.jpg
#   inflating: dataset_R_G_blur/X/X679.jpg
#   inflating: dataset_R_G_blur/X/X68 (2).jpg
#   inflating: dataset_R_G_blur/X/X68.jpg
#   inflating: dataset_R_G_blur/X/X680.jpg
#   inflating: dataset_R_G_blur/X/X681.jpg
#   inflating: dataset_R_G_blur/X/X682.jpg
#   inflating: dataset_R_G_blur/X/X683.jpg
#   inflating: dataset_R_G_blur/X/X684.jpg
#   inflating: dataset_R_G_blur/X/X685.jpg
#   inflating: dataset_R_G_blur/X/X686.jpg
#   inflating: dataset_R_G_blur/X/X687.jpg
#   inflating: dataset_R_G_blur/X/X688.jpg
#   inflating: dataset_R_G_blur/X/X689.jpg
#   inflating: dataset_R_G_blur/X/X69 (2).jpg
#   inflating: dataset_R_G_blur/X/X69.jpg
#   inflating: dataset_R_G_blur/X/X690.jpg
#   inflating: dataset_R_G_blur/X/X691.jpg
#   inflating: dataset_R_G_blur/X/X692.jpg
#   inflating: dataset_R_G_blur/X/X693.jpg
#   inflating: dataset_R_G_blur/X/X694.jpg
#   inflating: dataset_R_G_blur/X/X695.jpg
#   inflating: dataset_R_G_blur/X/X696.jpg
#   inflating: dataset_R_G_blur/X/X697.jpg
#   inflating: dataset_R_G_blur/X/X698.jpg
#   inflating: dataset_R_G_blur/X/X699.jpg
#   inflating: dataset_R_G_blur/X/X7 (2).jpg
#   inflating: dataset_R_G_blur/X/X7.jpg
#   inflating: dataset_R_G_blur/X/X70 (2).jpg
#   inflating: dataset_R_G_blur/X/X70.jpg
#   inflating: dataset_R_G_blur/X/X700.jpg
#   inflating: dataset_R_G_blur/X/X71 (2).jpg
#   inflating: dataset_R_G_blur/X/X71.jpg
#   inflating: dataset_R_G_blur/X/X72 (2).jpg
#   inflating: dataset_R_G_blur/X/X72.jpg
#   inflating: dataset_R_G_blur/X/X73 (2).jpg
#   inflating: dataset_R_G_blur/X/X73.jpg
#   inflating: dataset_R_G_blur/X/X74 (2).jpg
#   inflating: dataset_R_G_blur/X/X74.jpg
#   inflating: dataset_R_G_blur/X/X75 (2).jpg
#   inflating: dataset_R_G_blur/X/X75.jpg
#   inflating: dataset_R_G_blur/X/X76 (2).jpg
#   inflating: dataset_R_G_blur/X/X76.jpg
#   inflating: dataset_R_G_blur/X/X77 (2).jpg
#   inflating: dataset_R_G_blur/X/X77.jpg
#   inflating: dataset_R_G_blur/X/X78 (2).jpg
#   inflating: dataset_R_G_blur/X/X78.jpg
#   inflating: dataset_R_G_blur/X/X79 (2).jpg
#   inflating: dataset_R_G_blur/X/X79.jpg
#   inflating: dataset_R_G_blur/X/X8 (2).jpg
#   inflating: dataset_R_G_blur/X/X8.jpg
#   inflating: dataset_R_G_blur/X/X80 (2).jpg
#   inflating: dataset_R_G_blur/X/X80.jpg
#   inflating: dataset_R_G_blur/X/X81 (2).jpg
#   inflating: dataset_R_G_blur/X/X81.jpg
#   inflating: dataset_R_G_blur/X/X82 (2).jpg
#   inflating: dataset_R_G_blur/X/X82.jpg
#   inflating: dataset_R_G_blur/X/X83 (2).jpg
#   inflating: dataset_R_G_blur/X/X83.jpg
#   inflating: dataset_R_G_blur/X/X84 (2).jpg
#   inflating: dataset_R_G_blur/X/X84.jpg
#   inflating: dataset_R_G_blur/X/X85 (2).jpg
#   inflating: dataset_R_G_blur/X/X85.jpg
#   inflating: dataset_R_G_blur/X/X86 (2).jpg
#   inflating: dataset_R_G_blur/X/X86.jpg
#   inflating: dataset_R_G_blur/X/X87 (2).jpg
#   inflating: dataset_R_G_blur/X/X87.jpg
#   inflating: dataset_R_G_blur/X/X88 (2).jpg
#   inflating: dataset_R_G_blur/X/X88.jpg
#   inflating: dataset_R_G_blur/X/X89 (2).jpg
#   inflating: dataset_R_G_blur/X/X89.jpg
#   inflating: dataset_R_G_blur/X/X9 (2).jpg
#   inflating: dataset_R_G_blur/X/X9.jpg
#   inflating: dataset_R_G_blur/X/X90 (2).jpg
#   inflating: dataset_R_G_blur/X/X90.jpg
#   inflating: dataset_R_G_blur/X/X91 (2).jpg
#   inflating: dataset_R_G_blur/X/X91.jpg
#   inflating: dataset_R_G_blur/X/X92 (2).jpg
#   inflating: dataset_R_G_blur/X/X92.jpg
#   inflating: dataset_R_G_blur/X/X93 (2).jpg
#   inflating: dataset_R_G_blur/X/X93.jpg
#   inflating: dataset_R_G_blur/X/X94 (2).jpg
#   inflating: dataset_R_G_blur/X/X94.jpg
#   inflating: dataset_R_G_blur/X/X95 (2).jpg
#   inflating: dataset_R_G_blur/X/X95.jpg
#   inflating: dataset_R_G_blur/X/X96 (2).jpg
#   inflating: dataset_R_G_blur/X/X96.jpg
#   inflating: dataset_R_G_blur/X/X97 (2).jpg
#   inflating: dataset_R_G_blur/X/X97.jpg
#   inflating: dataset_R_G_blur/X/X98 (2).jpg
#   inflating: dataset_R_G_blur/X/X98.jpg
#   inflating: dataset_R_G_blur/X/X99 (2).jpg
#   inflating: dataset_R_G_blur/X/X99.jpg
#   inflating: dataset_R_G_blur/Y/0.jpg
#   inflating: dataset_R_G_blur/Y/1.jpg
#   inflating: dataset_R_G_blur/Y/10 (2).jpg
#   inflating: dataset_R_G_blur/Y/10.jpg
#   inflating: dataset_R_G_blur/Y/100 (2).jpg
#   inflating: dataset_R_G_blur/Y/100.jpg
#   inflating: dataset_R_G_blur/Y/101 (2).jpg
#   inflating: dataset_R_G_blur/Y/101.jpg
#   inflating: dataset_R_G_blur/Y/102 (2).jpg
#   inflating: dataset_R_G_blur/Y/102.jpg
#   inflating: dataset_R_G_blur/Y/103 (2).jpg
#   inflating: dataset_R_G_blur/Y/103.jpg
#   inflating: dataset_R_G_blur/Y/104 (2).jpg
#   inflating: dataset_R_G_blur/Y/104.jpg
#   inflating: dataset_R_G_blur/Y/105 (2).jpg
#   inflating: dataset_R_G_blur/Y/105.jpg
#   inflating: dataset_R_G_blur/Y/106 (2).jpg
#   inflating: dataset_R_G_blur/Y/106.jpg
#   inflating: dataset_R_G_blur/Y/107 (2).jpg
#   inflating: dataset_R_G_blur/Y/107.jpg
#   inflating: dataset_R_G_blur/Y/108 (2).jpg
#   inflating: dataset_R_G_blur/Y/108.jpg
#   inflating: dataset_R_G_blur/Y/109 (2).jpg
#   inflating: dataset_R_G_blur/Y/109.jpg
#   inflating: dataset_R_G_blur/Y/11 (2).jpg
#   inflating: dataset_R_G_blur/Y/11.jpg
#   inflating: dataset_R_G_blur/Y/110 (2).jpg
#   inflating: dataset_R_G_blur/Y/110.jpg
#   inflating: dataset_R_G_blur/Y/111 (2).jpg
#   inflating: dataset_R_G_blur/Y/111.jpg
#   inflating: dataset_R_G_blur/Y/112 (2).jpg
#   inflating: dataset_R_G_blur/Y/112.jpg
#   inflating: dataset_R_G_blur/Y/113 (2).jpg
#   inflating: dataset_R_G_blur/Y/113.jpg
#   inflating: dataset_R_G_blur/Y/114 (2).jpg
#   inflating: dataset_R_G_blur/Y/114.jpg
#   inflating: dataset_R_G_blur/Y/115 (2).jpg
#   inflating: dataset_R_G_blur/Y/115.jpg
#   inflating: dataset_R_G_blur/Y/116 (2).jpg
#   inflating: dataset_R_G_blur/Y/116.jpg
#   inflating: dataset_R_G_blur/Y/117 (2).jpg
#   inflating: dataset_R_G_blur/Y/117.jpg
#   inflating: dataset_R_G_blur/Y/118 (2).jpg
#   inflating: dataset_R_G_blur/Y/118.jpg
#   inflating: dataset_R_G_blur/Y/119 (2).jpg
#   inflating: dataset_R_G_blur/Y/119.jpg
#   inflating: dataset_R_G_blur/Y/12 (2).jpg
#   inflating: dataset_R_G_blur/Y/12.jpg
#   inflating: dataset_R_G_blur/Y/120 (2).jpg
#   inflating: dataset_R_G_blur/Y/120.jpg
#   inflating: dataset_R_G_blur/Y/121 (2).jpg
#   inflating: dataset_R_G_blur/Y/121.jpg
#   inflating: dataset_R_G_blur/Y/122 (2).jpg
#   inflating: dataset_R_G_blur/Y/122.jpg
#   inflating: dataset_R_G_blur/Y/123 (2).jpg
#   inflating: dataset_R_G_blur/Y/123.jpg
#   inflating: dataset_R_G_blur/Y/124 (2).jpg
#   inflating: dataset_R_G_blur/Y/124.jpg
#   inflating: dataset_R_G_blur/Y/125 (2).jpg
#   inflating: dataset_R_G_blur/Y/125.jpg
#   inflating: dataset_R_G_blur/Y/126 (2).jpg
#   inflating: dataset_R_G_blur/Y/126.jpg
#   inflating: dataset_R_G_blur/Y/127 (2).jpg
#   inflating: dataset_R_G_blur/Y/127.jpg
#   inflating: dataset_R_G_blur/Y/128 (2).jpg
#   inflating: dataset_R_G_blur/Y/128.jpg
#   inflating: dataset_R_G_blur/Y/129 (2).jpg
#   inflating: dataset_R_G_blur/Y/129.jpg
#   inflating: dataset_R_G_blur/Y/13 (2).jpg
#   inflating: dataset_R_G_blur/Y/13.jpg
#   inflating: dataset_R_G_blur/Y/130 (2).jpg
#   inflating: dataset_R_G_blur/Y/130.jpg
#   inflating: dataset_R_G_blur/Y/131 (2).jpg
#   inflating: dataset_R_G_blur/Y/131.jpg
#   inflating: dataset_R_G_blur/Y/132 (2).jpg
#   inflating: dataset_R_G_blur/Y/132.jpg
#   inflating: dataset_R_G_blur/Y/133 (2).jpg
#   inflating: dataset_R_G_blur/Y/133.jpg
#   inflating: dataset_R_G_blur/Y/134 (2).jpg
#   inflating: dataset_R_G_blur/Y/134.jpg
#   inflating: dataset_R_G_blur/Y/135 (2).jpg
#   inflating: dataset_R_G_blur/Y/135.jpg
#   inflating: dataset_R_G_blur/Y/136 (2).jpg
#   inflating: dataset_R_G_blur/Y/136.jpg
#   inflating: dataset_R_G_blur/Y/137 (2).jpg
#   inflating: dataset_R_G_blur/Y/137.jpg
#   inflating: dataset_R_G_blur/Y/138 (2).jpg
#   inflating: dataset_R_G_blur/Y/138.jpg
#   inflating: dataset_R_G_blur/Y/139 (2).jpg
#   inflating: dataset_R_G_blur/Y/139.jpg
# ...
#   inflating: dataset_R_G_blur/Z/Z450.jpg
#   inflating: dataset_R_G_blur/Z/Z451.jpg
#   inflating: dataset_R_G_blur/Z/Z452.jpg
#   inflating: dataset_R_G_blur/Z/Z453.jpg
#   inflating: dataset_R_G_blur/Z/Z454.jpg
#   inflating: dataset_R_G_blur/Z/Z455.jpg
#   inflating: dataset_R_G_blur/Z/Z456.jpg
#   inflating: dataset_R_G_blur/Z/Z457.jpg
#   inflating: dataset_R_G_blur/Z/Z458.jpg
#   inflating: dataset_R_G_blur/Z/Z459.jpg
#   inflating: dataset_R_G_blur/Z/Z46 (2).jpg
#   inflating: dataset_R_G_blur/Z/Z46.jpg
#   inflating: dataset_R_G_blur/Z/Z460.jpg
#   inflating: dataset_R_G_blur/Z/Z461.jpg
#   inflating: dataset_R_G_blur/Z/Z462.jpg
#   inflating: dataset_R_G_blur/Z/Z463.jpg
#   inflating: dataset_R_G_blur/Z/Z464.jpg
#   inflating: dataset_R_G_blur/Z/Z465.jpg
#   inflating: dataset_R_G_blur/Z/Z466.jpg
#   inflating: dataset_R_G_blur/Z/Z467.jpg
#   inflating: dataset_R_G_blur/Z/Z468.jpg
#   inflating: dataset_R_G_blur/Z/Z469.jpg
#   inflating: dataset_R_G_blur/Z/Z47 (2).jpg
#   inflating: dataset_R_G_blur/Z/Z47.jpg
#   inflating: dataset_R_G_blur/Z/Z470.jpg
#   inflating: dataset_R_G_blur/Z/Z471.jpg
#   inflating: dataset_R_G_blur/Z/Z472.jpg
#   inflating: dataset_R_G_blur/Z/Z473.jpg
#   inflating: dataset_R_G_blur/Z/Z474.jpg
#   inflating: dataset_R_G_blur/Z/Z475.jpg
#   inflating: dataset_R_G_blur/Z/Z476.jpg
#   inflating: dataset_R_G_blur/Z/Z477.jpg
#   inflating: dataset_R_G_blur/Z/Z478.jpg
#   inflating: dataset_R_G_blur/Z/Z479.jpg
#   inflating: dataset_R_G_blur/Z/Z48 (2).jpg
#   inflating: dataset_R_G_blur/Z/Z48.jpg
#   inflating: dataset_R_G_blur/Z/Z480.jpg
#   inflating: dataset_R_G_blur/Z/Z481.jpg
#   inflating: dataset_R_G_blur/Z/Z482.jpg
#   inflating: dataset_R_G_blur/Z/Z483.jpg
#   inflating: dataset_R_G_blur/Z/Z484.jpg
#   inflating: dataset_R_G_blur/Z/Z485.jpg
#   inflating: dataset_R_G_blur/Z/Z486.jpg
#   inflating: dataset_R_G_blur/Z/Z487.jpg
#   inflating: dataset_R_G_blur/Z/Z488.jpg
#   inflating: dataset_R_G_blur/Z/Z489.jpg
#   inflating: dataset_R_G_blur/Z/Z49 (2).jpg
#   inflating: dataset_R_G_blur/Z/Z49.jpg
#   inflating: dataset_R_G_blur/Z/Z490.jpg
#   inflating: dataset_R_G_blur/Z/Z491.jpg
#   inflating: dataset_R_G_blur/Z/Z492.jpg
#   inflating: dataset_R_G_blur/Z/Z493.jpg
#   inflating: dataset_R_G_blur/Z/Z494.jpg
#   inflating: dataset_R_G_blur/Z/Z495.jpg
#   inflating: dataset_R_G_blur/Z/Z496.jpg
#   inflating: dataset_R_G_blur/Z/Z497.jpg
#   inflating: dataset_R_G_blur/Z/Z498.jpg
#   inflating: dataset_R_G_blur/Z/Z499.jpg
#   inflating: dataset_R_G_blur/Z/Z5 (2).jpg
#   inflating: dataset_R_G_blur/Z/Z5.jpg
#   inflating: dataset_R_G_blur/Z/Z50 (2).jpg
#   inflating: dataset_R_G_blur/Z/Z50.jpg
#   inflating: dataset_R_G_blur/Z/Z500.jpg
#   inflating: dataset_R_G_blur/Z/Z501.jpg
#   inflating: dataset_R_G_blur/Z/Z502.jpg
#   inflating: dataset_R_G_blur/Z/Z503.jpg
#   inflating: dataset_R_G_blur/Z/Z504.jpg
#   inflating: dataset_R_G_blur/Z/Z505.jpg
#   inflating: dataset_R_G_blur/Z/Z506.jpg
#   inflating: dataset_R_G_blur/Z/Z507.jpg
#   inflating: dataset_R_G_blur/Z/Z508.jpg
#   inflating: dataset_R_G_blur/Z/Z509.jpg
#   inflating: dataset_R_G_blur/Z/Z51 (2).jpg
#   inflating: dataset_R_G_blur/Z/Z51.jpg
#   inflating: dataset_R_G_blur/Z/Z510.jpg
#   inflating: dataset_R_G_blur/Z/Z511.jpg
#   inflating: dataset_R_G_blur/Z/Z512.jpg
#   inflating: dataset_R_G_blur/Z/Z513.jpg
#   inflating: dataset_R_G_blur/Z/Z514.jpg
#   inflating: dataset_R_G_blur/Z/Z515.jpg
#   inflating: dataset_R_G_blur/Z/Z516.jpg
#   inflating: dataset_R_G_blur/Z/Z517.jpg
#   inflating: dataset_R_G_blur/Z/Z518.jpg
#   inflating: dataset_R_G_blur/Z/Z519.jpg
#   inflating: dataset_R_G_blur/Z/Z52 (2).jpg
#   inflating: dataset_R_G_blur/Z/Z52.jpg
#   inflating: dataset_R_G_blur/Z/Z520.jpg
#   inflating: dataset_R_G_blur/Z/Z521.jpg
#   inflating: dataset_R_G_blur/Z/Z522.jpg
#   inflating: dataset_R_G_blur/Z/Z523.jpg
#   inflating: dataset_R_G_blur/Z/Z524.jpg
#   inflating: dataset_R_G_blur/Z/Z525.jpg
#   inflating: dataset_R_G_blur/Z/Z526.jpg
#   inflating: dataset_R_G_blur/Z/Z527.jpg
#   inflating: dataset_R_G_blur/Z/Z528.jpg
#   inflating: dataset_R_G_blur/Z/Z529.jpg
#   inflating: dataset_R_G_blur/Z/Z53 (2).jpg
#   inflating: dataset_R_G_blur/Z/Z53.jpg
#   inflating: dataset_R_G_blur/Z/Z530.jpg
#   inflating: dataset_R_G_blur/Z/Z531.jpg
#   inflating: dataset_R_G_blur/Z/Z532.jpg
#   inflating: dataset_R_G_blur/Z/Z533.jpg
#   inflating: dataset_R_G_blur/Z/Z534.jpg
#   inflating: dataset_R_G_blur/Z/Z535.jpg
#   inflating: dataset_R_G_blur/Z/Z536.jpg
#   inflating: dataset_R_G_blur/Z/Z537.jpg
#   inflating: dataset_R_G_blur/Z/Z538.jpg
#   inflating: dataset_R_G_blur/Z/Z539.jpg
#   inflating: dataset_R_G_blur/Z/Z54 (2).jpg
#   inflating: dataset_R_G_blur/Z/Z54.jpg
#   inflating: dataset_R_G_blur/Z/Z540.jpg
#   inflating: dataset_R_G_blur/Z/Z541.jpg
#   inflating: dataset_R_G_blur/Z/Z542.jpg
#   inflating: dataset_R_G_blur/Z/Z543.jpg
#   inflating: dataset_R_G_blur/Z/Z544.jpg
#   inflating: dataset_R_G_blur/Z/Z545.jpg
#   inflating: dataset_R_G_blur/Z/Z546.jpg
#   inflating: dataset_R_G_blur/Z/Z547.jpg
#   inflating: dataset_R_G_blur/Z/Z548.jpg
#   inflating: dataset_R_G_blur/Z/Z549.jpg
#   inflating: dataset_R_G_blur/Z/Z55 (2).jpg
#   inflating: dataset_R_G_blur/Z/Z55.jpg
#   inflating: dataset_R_G_blur/Z/Z550.jpg
#   inflating: dataset_R_G_blur/Z/Z551.jpg
#   inflating: dataset_R_G_blur/Z/Z552.jpg
#   inflating: dataset_R_G_blur/Z/Z553.jpg
#   inflating: dataset_R_G_blur/Z/Z554.jpg
#   inflating: dataset_R_G_blur/Z/Z555.jpg
#   inflating: dataset_R_G_blur/Z/Z556.jpg
#   inflating: dataset_R_G_blur/Z/Z557.jpg
#   inflating: dataset_R_G_blur/Z/Z558.jpg
#   inflating: dataset_R_G_blur/Z/Z559.jpg
#   inflating: dataset_R_G_blur/Z/Z56 (2).jpg
#   inflating: dataset_R_G_blur/Z/Z56.jpg
#   inflating: dataset_R_G_blur/Z/Z560.jpg
#   inflating: dataset_R_G_blur/Z/Z561.jpg
#   inflating: dataset_R_G_blur/Z/Z562.jpg
#   inflating: dataset_R_G_blur/Z/Z563.jpg
#   inflating: dataset_R_G_blur/Z/Z564.jpg
#   inflating: dataset_R_G_blur/Z/Z565.jpg
#   inflating: dataset_R_G_blur/Z/Z566.jpg
#   inflating: dataset_R_G_blur/Z/Z567.jpg
#   inflating: dataset_R_G_blur/Z/Z568.jpg
#   inflating: dataset_R_G_blur/Z/Z569.jpg
#   inflating: dataset_R_G_blur/Z/Z57 (2).jpg
#   inflating: dataset_R_G_blur/Z/Z57.jpg
#   inflating: dataset_R_G_blur/Z/Z570.jpg
#   inflating: dataset_R_G_blur/Z/Z571.jpg
#   inflating: dataset_R_G_blur/Z/Z572.jpg
#   inflating: dataset_R_G_blur/Z/Z573.jpg
#   inflating: dataset_R_G_blur/Z/Z574.jpg
#   inflating: dataset_R_G_blur/Z/Z575.jpg
#   inflating: dataset_R_G_blur/Z/Z576.jpg
#   inflating: dataset_R_G_blur/Z/Z577.jpg
#   inflating: dataset_R_G_blur/Z/Z578.jpg
#   inflating: dataset_R_G_blur/Z/Z579.jpg
#   inflating: dataset_R_G_blur/Z/Z58 (2).jpg
#   inflating: dataset_R_G_blur/Z/Z58.jpg
#   inflating: dataset_R_G_blur/Z/Z580.jpg
#   inflating: dataset_R_G_blur/Z/Z581.jpg
#   inflating: dataset_R_G_blur/Z/Z582.jpg
#   inflating: dataset_R_G_blur/Z/Z583.jpg
#   inflating: dataset_R_G_blur/Z/Z584.jpg
#   inflating: dataset_R_G_blur/Z/Z585.jpg
#   inflating: dataset_R_G_blur/Z/Z586.jpg
#   inflating: dataset_R_G_blur/Z/Z587.jpg
#   inflating: dataset_R_G_blur/Z/Z588.jpg
#   inflating: dataset_R_G_blur/Z/Z589.jpg
#   inflating: dataset_R_G_blur/Z/Z59 (2).jpg
#   inflating: dataset_R_G_blur/Z/Z59.jpg
#   inflating: dataset_R_G_blur/Z/Z590.jpg
#   inflating: dataset_R_G_blur/Z/Z591.jpg
#   inflating: dataset_R_G_blur/Z/Z592.jpg
#   inflating: dataset_R_G_blur/Z/Z593.jpg
#   inflating: dataset_R_G_blur/Z/Z594.jpg
#   inflating: dataset_R_G_blur/Z/Z595.jpg
#   inflating: dataset_R_G_blur/Z/Z596.jpg
#   inflating: dataset_R_G_blur/Z/Z597.jpg
#   inflating: dataset_R_G_blur/Z/Z598.jpg
#   inflating: dataset_R_G_blur/Z/Z599.jpg
#   inflating: dataset_R_G_blur/Z/Z6 (2).jpg
#   inflating: dataset_R_G_blur/Z/Z6.jpg
#   inflating: dataset_R_G_blur/Z/Z60 (2).jpg
#   inflating: dataset_R_G_blur/Z/Z60.jpg
#   inflating: dataset_R_G_blur/Z/Z600.jpg
#   inflating: dataset_R_G_blur/Z/Z601.jpg
#   inflating: dataset_R_G_blur/Z/Z602.jpg
#   inflating: dataset_R_G_blur/Z/Z603.jpg
#   inflating: dataset_R_G_blur/Z/Z604.jpg
#   inflating: dataset_R_G_blur/Z/Z605.jpg
#   inflating: dataset_R_G_blur/Z/Z606.jpg
#   inflating: dataset_R_G_blur/Z/Z607.jpg
#   inflating: dataset_R_G_blur/Z/Z608.jpg
#   inflating: dataset_R_G_blur/Z/Z609.jpg
#   inflating: dataset_R_G_blur/Z/Z61 (2).jpg
#   inflating: dataset_R_G_blur/Z/Z61.jpg
#   inflating: dataset_R_G_blur/Z/Z610.jpg
#   inflating: dataset_R_G_blur/Z/Z611.jpg
#   inflating: dataset_R_G_blur/Z/Z612.jpg
#   inflating: dataset_R_G_blur/Z/Z613.jpg
#   inflating: dataset_R_G_blur/Z/Z614.jpg
#   inflating: dataset_R_G_blur/Z/Z615.jpg
#   inflating: dataset_R_G_blur/Z/Z616.jpg
#   inflating: dataset_R_G_blur/Z/Z617.jpg
#   inflating: dataset_R_G_blur/Z/Z618.jpg
#   inflating: dataset_R_G_blur/Z/Z619.jpg
#   inflating: dataset_R_G_blur/Z/Z62 (2).jpg
#   inflating: dataset_R_G_blur/Z/Z62.jpg
#   inflating: dataset_R_G_blur/Z/Z620.jpg
#   inflating: dataset_R_G_blur/Z/Z621.jpg
#   inflating: dataset_R_G_blur/Z/Z622.jpg
#   inflating: dataset_R_G_blur/Z/Z623.jpg
#   inflating: dataset_R_G_blur/Z/Z624.jpg
#   inflating: dataset_R_G_blur/Z/Z625.jpg
#   inflating: dataset_R_G_blur/Z/Z626.jpg
#   inflating: dataset_R_G_blur/Z/Z627.jpg
#   inflating: dataset_R_G_blur/Z/Z628.jpg
#   inflating: dataset_R_G_blur/Z/Z629.jpg
#   inflating: dataset_R_G_blur/Z/Z63 (2).jpg
#   inflating: dataset_R_G_blur/Z/Z63.jpg
#   inflating: dataset_R_G_blur/Z/Z630.jpg
#   inflating: dataset_R_G_blur/Z/Z631.jpg
#   inflating: dataset_R_G_blur/Z/Z632.jpg
#   inflating: dataset_R_G_blur/Z/Z633.jpg
#   inflating: dataset_R_G_blur/Z/Z634.jpg
#   inflating: dataset_R_G_blur/Z/Z635.jpg
#   inflating: dataset_R_G_blur/Z/Z636.jpg
#   inflating: dataset_R_G_blur/Z/Z637.jpg
#   inflating: dataset_R_G_blur/Z/Z638.jpg
#   inflating: dataset_R_G_blur/Z/Z639.jpg
#   inflating: dataset_R_G_blur/Z/Z64 (2).jpg
#   inflating: dataset_R_G_blur/Z/Z64.jpg
#   inflating: dataset_R_G_blur/Z/Z640.jpg
#   inflating: dataset_R_G_blur/Z/Z641.jpg
#   inflating: dataset_R_G_blur/Z/Z642.jpg
#   inflating: dataset_R_G_blur/Z/Z643.jpg
#   inflating: dataset_R_G_blur/Z/Z644.jpg
#   inflating: dataset_R_G_blur/Z/Z645.jpg
#   inflating: dataset_R_G_blur/Z/Z646.jpg
#   inflating: dataset_R_G_blur/Z/Z647.jpg
#   inflating: dataset_R_G_blur/Z/Z648.jpg
#   inflating: dataset_R_G_blur/Z/Z649.jpg
#   inflating: dataset_R_G_blur/Z/Z65 (2).jpg
#   inflating: dataset_R_G_blur/Z/Z65.jpg
#   inflating: dataset_R_G_blur/Z/Z650.jpg
#   inflating: dataset_R_G_blur/Z/Z651.jpg
#   inflating: dataset_R_G_blur/Z/Z652.jpg
#   inflating: dataset_R_G_blur/Z/Z653.jpg
#   inflating: dataset_R_G_blur/Z/Z654.jpg
#   inflating: dataset_R_G_blur/Z/Z655.jpg
#   inflating: dataset_R_G_blur/Z/Z656.jpg
#   inflating: dataset_R_G_blur/Z/Z657.jpg
#   inflating: dataset_R_G_blur/Z/Z658.jpg
#   inflating: dataset_R_G_blur/Z/Z659.jpg
#   inflating: dataset_R_G_blur/Z/Z66 (2).jpg
#   inflating: dataset_R_G_blur/Z/Z66.jpg
#   inflating: dataset_R_G_blur/Z/Z660.jpg
#   inflating: dataset_R_G_blur/Z/Z661.jpg
#   inflating: dataset_R_G_blur/Z/Z662.jpg
#   inflating: dataset_R_G_blur/Z/Z663.jpg
#   inflating: dataset_R_G_blur/Z/Z664.jpg
#   inflating: dataset_R_G_blur/Z/Z665.jpg
#   inflating: dataset_R_G_blur/Z/Z666.jpg
#   inflating: dataset_R_G_blur/Z/Z667.jpg
#   inflating: dataset_R_G_blur/Z/Z668.jpg
#   inflating: dataset_R_G_blur/Z/Z669.jpg
#   inflating: dataset_R_G_blur/Z/Z67 (2).jpg
#   inflating: dataset_R_G_blur/Z/Z67.jpg
#   inflating: dataset_R_G_blur/Z/Z670.jpg
#   inflating: dataset_R_G_blur/Z/Z671.jpg
#   inflating: dataset_R_G_blur/Z/Z672.jpg
#   inflating: dataset_R_G_blur/Z/Z673.jpg
#   inflating: dataset_R_G_blur/Z/Z674.jpg
#   inflating: dataset_R_G_blur/Z/Z675.jpg
#   inflating: dataset_R_G_blur/Z/Z676.jpg
#   inflating: dataset_R_G_blur/Z/Z677.jpg
#   inflating: dataset_R_G_blur/Z/Z678.jpg
#   inflating: dataset_R_G_blur/Z/Z679.jpg
#   inflating: dataset_R_G_blur/Z/Z68 (2).jpg
#   inflating: dataset_R_G_blur/Z/Z68.jpg
#   inflating: dataset_R_G_blur/Z/Z680.jpg
#   inflating: dataset_R_G_blur/Z/Z681.jpg
#   inflating: dataset_R_G_blur/Z/Z682.jpg
#   inflating: dataset_R_G_blur/Z/Z683.jpg
#   inflating: dataset_R_G_blur/Z/Z684.jpg
#   inflating: dataset_R_G_blur/Z/Z685.jpg
#   inflating: dataset_R_G_blur/Z/Z686.jpg
#   inflating: dataset_R_G_blur/Z/Z687.jpg
#   inflating: dataset_R_G_blur/Z/Z688.jpg
#   inflating: dataset_R_G_blur/Z/Z689.jpg
#   inflating: dataset_R_G_blur/Z/Z69 (2).jpg
#   inflating: dataset_R_G_blur/Z/Z69.jpg
#   inflating: dataset_R_G_blur/Z/Z690.jpg
#   inflating: dataset_R_G_blur/Z/Z691.jpg
#   inflating: dataset_R_G_blur/Z/Z692.jpg
#   inflating: dataset_R_G_blur/Z/Z693.jpg
#   inflating: dataset_R_G_blur/Z/Z694.jpg
#   inflating: dataset_R_G_blur/Z/Z695.jpg
#   inflating: dataset_R_G_blur/Z/Z696.jpg
#   inflating: dataset_R_G_blur/Z/Z697.jpg
#   inflating: dataset_R_G_blur/Z/Z698.jpg
#   inflating: dataset_R_G_blur/Z/Z699.jpg
#   inflating: dataset_R_G_blur/Z/Z7 (2).jpg
#   inflating: dataset_R_G_blur/Z/Z7.jpg
#   inflating: dataset_R_G_blur/Z/Z70 (2).jpg
#   inflating: dataset_R_G_blur/Z/Z70.jpg
#   inflating: dataset_R_G_blur/Z/Z700.jpg
#   inflating: dataset_R_G_blur/Z/Z71 (2).jpg
#   inflating: dataset_R_G_blur/Z/Z71.jpg
#   inflating: dataset_R_G_blur/Z/Z72 (2).jpg
#   inflating: dataset_R_G_blur/Z/Z72.jpg
#   inflating: dataset_R_G_blur/Z/Z73 (2).jpg
#   inflating: dataset_R_G_blur/Z/Z73.jpg
#   inflating: dataset_R_G_blur/Z/Z74 (2).jpg
#   inflating: dataset_R_G_blur/Z/Z74.jpg
#   inflating: dataset_R_G_blur/Z/Z75 (2).jpg
#   inflating: dataset_R_G_blur/Z/Z75.jpg
#   inflating: dataset_R_G_blur/Z/Z76 (2).jpg
#   inflating: dataset_R_G_blur/Z/Z76.jpg
#   inflating: dataset_R_G_blur/Z/Z77 (2).jpg
#   inflating: dataset_R_G_blur/Z/Z77.jpg
#   inflating: dataset_R_G_blur/Z/Z78 (2).jpg
#   inflating: dataset_R_G_blur/Z/Z78.jpg
#   inflating: dataset_R_G_blur/Z/Z79 (2).jpg
#   inflating: dataset_R_G_blur/Z/Z79.jpg
#   inflating: dataset_R_G_blur/Z/Z8 (2).jpg
#   inflating: dataset_R_G_blur/Z/Z8.jpg
#   inflating: dataset_R_G_blur/Z/Z80 (2).jpg
#   inflating: dataset_R_G_blur/Z/Z80.jpg
#   inflating: dataset_R_G_blur/Z/Z81 (2).jpg
#   inflating: dataset_R_G_blur/Z/Z81.jpg
#   inflating: dataset_R_G_blur/Z/Z82 (2).jpg
#   inflating: dataset_R_G_blur/Z/Z82.jpg
#   inflating: dataset_R_G_blur/Z/Z83 (2).jpg
#   inflating: dataset_R_G_blur/Z/Z83.jpg
#   inflating: dataset_R_G_blur/Z/Z84 (2).jpg
#   inflating: dataset_R_G_blur/Z/Z84.jpg
#   inflating: dataset_R_G_blur/Z/Z85 (2).jpg
#   inflating: dataset_R_G_blur/Z/Z85.jpg
#   inflating: dataset_R_G_blur/Z/Z86 (2).jpg
#   inflating: dataset_R_G_blur/Z/Z86.jpg
#   inflating: dataset_R_G_blur/Z/Z87 (2).jpg
#   inflating: dataset_R_G_blur/Z/Z87.jpg
#   inflating: dataset_R_G_blur/Z/Z88 (2).jpg
#   inflating: dataset_R_G_blur/Z/Z88.jpg
#   inflating: dataset_R_G_blur/Z/Z89 (2).jpg
#   inflating: dataset_R_G_blur/Z/Z89.jpg
#   inflating: dataset_R_G_blur/Z/Z9 (2).jpg
#   inflating: dataset_R_G_blur/Z/Z9.jpg
#   inflating: dataset_R_G_blur/Z/Z90 (2).jpg
#   inflating: dataset_R_G_blur/Z/Z90.jpg
#   inflating: dataset_R_G_blur/Z/Z91 (2).jpg
#   inflating: dataset_R_G_blur/Z/Z91.jpg
#   inflating: dataset_R_G_blur/Z/Z92 (2).jpg
#   inflating: dataset_R_G_blur/Z/Z92.jpg
#   inflating: dataset_R_G_blur/Z/Z93 (2).jpg
#   inflating: dataset_R_G_blur/Z/Z93.jpg
#   inflating: dataset_R_G_blur/Z/Z94 (2).jpg
#   inflating: dataset_R_G_blur/Z/Z94.jpg
#   inflating: dataset_R_G_blur/Z/Z95 (2).jpg
#   inflating: dataset_R_G_blur/Z/Z95.jpg
#   inflating: dataset_R_G_blur/Z/Z96 (2).jpg
#   inflating: dataset_R_G_blur/Z/Z96.jpg
#   inflating: dataset_R_G_blur/Z/Z97 (2).jpg
#   inflating: dataset_R_G_blur/Z/Z97.jpg
#   inflating: dataset_R_G_blur/Z/Z98 (2).jpg
#   inflating: dataset_R_G_blur/Z/Z98.jpg
#   inflating: dataset_R_G_blur/Z/Z99 (2).jpg
#   inflating: dataset_R_G_blur/Z/Z99.jpg

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import backend as K
from tensorflow.keras.layers import Dense, Activation,Dropout,Conv2D, MaxPooling2D,BatchNormalization, Flatten
from tensorflow.keras.optimizers import Adam, Adamax
from tensorflow.keras.metrics import categorical_crossentropy
from tensorflow.keras import regularizers
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Model, load_model, Sequential
import numpy as np
import pandas as pd
import shutil
import time
import cv2 as cv2
from tqdm import tqdm
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
from matplotlib.pyplot import imshow
import os
import seaborn as sns
sns.set_style('darkgrid')
from PIL import Image
from sklearn.metrics import confusion_matrix, classification_report
from IPython.core.display import display, HTML

# %%
import logging
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'  # FATAL
logging.getLogger('tensorflow').setLevel(logging.FATAL)

# %%
fpath=r'/content/dataset_R_G_blur/0/01 (2).jpg'
img=plt.imread(fpath)
print (img.shape)
imshow(img)
# Out:
# (300, 500)

# %%
sdir=r'/content/dataset_R_G_blur'
filepaths=[]
labels=[]
classlist=os.listdir(sdir)
for klass in classlist:
    classpath=os.path.join(sdir, klass)
    flist=os.listdir(classpath)
    for f in flist:
        fpath=os.path.join(classpath,f)        
        filepaths.append(fpath)
        labels.append(klass)
Fseries= pd.Series(filepaths, name='filepaths')
Lseries=pd.Series(labels, name='labels') 
df=pd.concat([Fseries, Lseries], axis=1)
print('df length: ', len(df))
balance=df['labels'].value_counts()
print (balance)
# Out:
# df length:  71257
# O    2006
# W    2000
# C    2000
# F    2000
# 0    2000
# J    2000
# N    2000
# E    2000
# 5    2000
# 9    2000
# 3    2000
# L    2000
# Z    2000
# 4    2000
# K    2000
# T    2000
# 7    2000
# Y    2000
# 2    2000
# 1    2000
# X    2000
# M    2000
# 6    2000
# B    2000
# G    2000
# U    2000
# D    2000
# R    2000
# Q    2000
# V    2000
# S    2000
# A    1999
# 8    1994
# I    1983
# P    1975
# H    1300
# Name: labels, dtype: int64

# %%
print ('original number of classes: ', len(df['labels'].unique()))     
size=500
samples=[]
group=df.groupby(labels)
for label in df['labels'].unique():
    Lgroup=group.get_group(label)
    count=int(Lgroup['labels'].value_counts()) 
    
    if count>=56:
        sample=Lgroup.sample(size, axis=0)
        samples.append(sample) 
df=pd.concat(samples, axis=0).reset_index(drop=True)
print (len(df))
print ('final number of classes: ', len(df['labels'].unique()))       
print (df['labels'].value_counts())
# Out:
# original number of classes:  36
# 18000
# final number of classes:  36
# W    500
# 7    500
# 0    500
# J    500
# N    500
# E    500
# I    500
# 5    500
# C    500
# 9    500
# L    500
# O    500
# Z    500
# 4    500
# K    500
# H    500
# T    500
# F    500
# Y    500
# 3    500
# U    500
# 8    500
# X    500
# M    500
# A    500
# 6    500
# B    500
# 1    500
# 2    500
# D    500
# R    500
# P    500
# Q    500
# V    500
# G    500
# S    500
# Name: labels, dtype: int64

# %%
train_split=.9
valid_split=.05
dummy_split=valid_split/(1-train_split)
train_df, dummy_df=train_test_split(df, train_size=train_split, shuffle=True, random_state=123)
valid_df, test_df=train_test_split(dummy_df, train_size=dummy_split, shuffle=True, random_state=123)
print('train_df length: ', len(train_df), '  test_df length: ', len(test_df), '  valid_df length: ' ,len(valid_df))
# Out:
# train_df length:  16200   test_df length:  900   valid_df length:  900

# %%
height=128
width=200
channels=3
batch_size=40
img_shape=(height, width, channels)
img_size=(height, width)
length=len(test_df)
test_batch_size=sorted([int(length/n) for n in range(1,length+1) if length % n ==0 and length/n<=80],reverse=True)[0]  
test_steps=int(length/test_batch_size)
print ( 'test batch size: ' ,test_batch_size, '  test steps: ', test_steps)
def scalar(img):
    #img=img/127.5-1
    return img 
trgen=ImageDataGenerator(preprocessing_function=scalar, horizontal_flip=True)
tvgen=ImageDataGenerator(preprocessing_function=scalar)
train_gen=trgen.flow_from_dataframe( train_df, x_col='filepaths', y_col='labels', target_size=img_size, class_mode='categorical',
                                    color_mode='rgb', shuffle=True, batch_size=batch_size)
test_gen=tvgen.flow_from_dataframe( test_df, x_col='filepaths', y_col='labels', target_size=img_size, class_mode='categorical',
                                    color_mode='rgb', shuffle=False, batch_size=test_batch_size)
valid_gen=tvgen.flow_from_dataframe( valid_df, x_col='filepaths', y_col='labels', target_size=img_size, class_mode='categorical',
                                    color_mode='rgb', shuffle=True, batch_size=batch_size)
classes=list(train_gen.class_indices.keys())
class_count=len(classes)
train_steps=int(len(train_gen.labels)/batch_size)
# Out:
# test batch size:  75   test steps:  12
# Found 16200 validated image filenames belonging to 36 classes.
# Found 900 validated image filenames belonging to 36 classes.
# Found 900 validated image filenames belonging to 36 classes.

# %%
def show_image_samples(gen ):
    t_dict=gen.class_indices
    classes=list(t_dict.keys())    
    images,labels=next(gen) # get a sample batch from the generator 
    plt.figure(figsize=(20, 20))
    length=len(labels)
    if length<25:   #show maximum of 25 images
        r=length
    else:
        r=25
    for i in range(r):
        plt.subplot(5, 5, i + 1)
        image=images[i]/255
        plt.imshow(image)
        index=np.argmax(labels[i])
        class_name=classes[index]
        plt.title(class_name, color='blue', fontsize=16)
        plt.axis('off')
    plt.show()

# %%
show_image_samples(train_gen)

# %%
def print_in_color(txt_msg,fore_tupple,back_tupple,):
    #prints the text_msg in the foreground color specified by fore_tupple with the background specified by back_tupple 
    #text_msg is the text, fore_tupple is foregroud color tupple (r,g,b), back_tupple is background tupple (r,g,b)
    rf,gf,bf=fore_tupple
    rb,gb,bb=back_tupple
    msg='{0}' + txt_msg
    mat='\33[38;2;' + str(rf) +';' + str(gf) + ';' + str(bf) + ';48;2;' + str(rb) + ';' +str(gb) + ';' + str(bb) +'m' 
    print(msg .format(mat), flush=True)
    print('\33[0m', flush=True) # returns default print color to back to black
    return

# %%
model_name='InceptionResNetV2'
base_model=tf.keras.applications.InceptionResNetV2(include_top=False, weights="imagenet",input_shape=img_shape, pooling='max') 
x=base_model.output
x=keras.layers.BatchNormalization(axis=-1, momentum=0.99, epsilon=0.001 )(x)
x = Dense(128, kernel_regularizer = regularizers.l2(l = 0.016),activity_regularizer=regularizers.l1(0.006),
                bias_regularizer=regularizers.l1(0.006) ,activation='relu')(x)
x=Dropout(rate=.45, seed=123)(x)        
output=Dense(class_count, activation='softmax')(x)
model=Model(inputs=base_model.input, outputs=output)
model.compile(Adamax(lr=.001), loss='categorical_crossentropy', metrics=['accuracy'])
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/inception_resnet_v2/inception_resnet_v2_weights_tf_dim_ordering_tf_kernels_notop.h5
# 219055592/219055592 [==============================] - 2s 0us/step
# /usr/local/lib/python3.8/dist-packages/keras/optimizers/optimizer_v2/adamax.py:95: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adamax, self).__init__(name, **kwargs)

# %%
class LRA(keras.callbacks.Callback):
    reset=False
    count=0
    stop_count=0
    tepochs=0
    def __init__(self,model, patience,stop_patience, threshold, factor, dwell, model_name, freeze,batches, initial_epoch):
        super(LRA, self).__init__()
        self.model=model
        self.patience=patience # specifies how many epochs without improvement before learning rate is adjusted
        self.stop_patience=stop_patience
        self.threshold=threshold # specifies training accuracy threshold when lr will be adjusted based on validation loss
        self.factor=factor # factor by which to reduce the learning rate
        self.dwell=dwell
        self.lr=float(tf.keras.backend.get_value(model.optimizer.lr)) # get the initiallearning rate and save it in self.lr
        self.highest_tracc=0.0 # set highest training accuracy to 0
        self.lowest_vloss=np.inf # set lowest validation loss to infinity
        #self.count=0 # initialize counter that counts epochs with no improvement
        #self.stop_count=0 # initialize counter that counts how manytimes lr has been adjustd with no improvement  
        self.initial_epoch=initial_epoch 
        self.batches=batches
        #self.epochs=epochs
        best_weights=self.model.get_weights() # set a class vaiable so weights can be loaded after training is completed        
        msg=' '
        if freeze==True:
            msgs=f' Starting training using  base model { model_name} with weights frozen to imagenet weights initializing LRA callback'
        else:
            msgs=f' Starting training using base model { model_name} training all layers '            
        print_in_color (msgs, (244, 252, 3), (55,65,80)) 
    def on_train_begin(self, logs=None):
        msg='{0:^8s}{1:^10s}{2:^9s}{3:^9s}{4:^9s}{5:^9s}{6:^9s}{7:^10s}{8:^8s}{9:^8s}'.format('Epoch', 'Loss', 'Accuracy',
                                                                                              'V_loss','V_acc', 'LR', 'Next LR', 'Monitor', 'Duration', 'Batch')
        print_in_color(msg, (244,252,3), (55,65,80)) 
        
    def on_train_batch_begin(self, batch, logs=None):
        msg='{0:83s}{1:4s}of {2:5s}'.format(' ', str(batch), str(self.batches))
        print(msg, '\r', end='') # prints over on the same line to show running batch count
        
        
    def on_epoch_begin(self,epoch, logs=None):
        self.now= time.time()
        
    def on_epoch_end(self, epoch, logs=None):  # method runs on the end of each epoch
        later=time.time()
        duration=later-self.now 
        lr=float(tf.keras.backend.get_value(self.model.optimizer.lr)) # get the current learning rate
        current_lr=lr
        v_loss=logs.get('val_loss')  # get the validation loss for this epoch
        acc=logs.get('accuracy')  # get training accuracy 
        v_acc=logs.get('val_accuracy')
        loss=logs.get('loss')
        #print ( '\n',v_loss, self.lowest_vloss, acc, self.highest_tracc)
        if acc < self.threshold: # if training accuracy is below threshold adjust lr based on training accuracy
            monitor='accuracy'
            if acc>self.highest_tracc: # training accuracy improved in the epoch                
                self.highest_tracc=acc # set new highest training accuracy
                LRA.best_weights=self.model.get_weights() # traing accuracy improved so save the weights
                self.count=0 # set count to 0 since training accuracy improved
                self.stop_count=0 # set stop counter to 0
                if v_loss<self.lowest_vloss:
                    self.lowest_vloss=v_loss
                color= (0,255,0)
                self.lr=lr
            else: 
                # training accuracy did not improve check if this has happened for patience number of epochs
                # if so adjust learning rate
                if self.count>=self.patience -1:
                    color=(245, 170, 66)
                    self.lr= lr* self.factor # adjust the learning by factor
                    tf.keras.backend.set_value(self.model.optimizer.lr, self.lr) # set the learning rate in the optimizer
                    self.count=0 # reset the count to 0
                    self.stop_count=self.stop_count + 1
                    if self.dwell:
                        self.model.set_weights(LRA.best_weights) # return to better point in N space                        
                    else:
                        if v_loss<self.lowest_vloss:
                            self.lowest_vloss=v_loss                                    
                else:
                    self.count=self.count +1 # increment patience counter                    
        else: # training accuracy is above threshold so adjust learning rate based on validation loss
            monitor='val_loss'
            if v_loss< self.lowest_vloss: # check if the validation loss improved 
                self.lowest_vloss=v_loss # replace lowest validation loss with new validation loss                
                LRA.best_weights=self.model.get_weights() # validation loss improved so save the weights
                self.count=0 # reset count since validation loss improved  
                self.stop_count=0  
                color=(0,255,0)
                self.lr=lr
            else: # validation loss did not improve
                if self.count>=self.patience-1:
                    color=(245, 170, 66)
                    self.lr=self.lr * self.factor # adjust the learning rate                    
                    self.stop_count=self.stop_count + 1 # increment stop counter because lr was adjusted 
                    self.count=0 # reset counter
                    tf.keras.backend.set_value(self.model.optimizer.lr, self.lr) # set the learning rate in the optimizer
                    if self.dwell:
                        self.model.set_weights(LRA.best_weights) # return to better point in N space
                else: 
                    self.count =self.count +1 # increment the patience counter                    
                if acc>self.highest_tracc:
                    self.highest_tracc= acc
        msg=f'{str(epoch+1):^3s}/{str(LRA.tepochs):4s} {loss:^9.3f}{acc*100:^9.3f}{v_loss:^9.5f}{v_acc*100:^9.3f}{current_lr:^9.5f}{self.lr:^9.5f}{monitor:^11s}{duration:^8.2f}'
        print_in_color (msg,color, (55,65,80))
        if self.stop_count> self.stop_patience - 1: # check if learning rate has been adjusted stop_count times with no improvement
            msg=f' training has been halted at epoch {epoch + 1} after {self.stop_patience} adjustments of learning rate with no improvement'
            print_in_color(msg, (0,255,0), (55,65,80))
            self.model.stop_training = True # stop training

# %%
epochs = 3
patience= 1 # number of epochs to wait to adjust lr if monitored value does not improve
stop_patience =3 # number of epochs to wait before stopping training if monitored value does not improve
threshold=.9 # if train accuracy is < threshhold adjust monitor accuracy, else monitor validation loss
factor=.5 # factor to reduce lr by
dwell=True # experimental, if True and monitored metric does not improve on current epoch set  model weights st back to weights of previous epoch
freeze=False # if true free weights of  the base model
batches=train_steps
callbacks=[LRA(model=model,patience=patience,stop_patience=stop_patience, threshold=threshold,
                   factor=factor,dwell=dwell, model_name=model_name, freeze=freeze, batches=batches,initial_epoch=0 )]
LRA.tepochs=epochs  # used to determine value of last epoch for printing
history=model.fit(x=train_gen,  epochs=epochs, verbose=0, callbacks=callbacks,  validation_data=valid_gen,
               validation_steps=None,  shuffle=False,  initial_epoch=0)
# Out:
#  Starting training using base model InceptionResNetV2 training all layers
#
#  Epoch     Loss   Accuracy  V_loss    V_acc     LR     Next LR  Monitor  Duration Batch

# %%
def tr_plot(tr_data, start_epoch):
    #Plot the training and validation data
    tacc=tr_data.history['accuracy']
    tloss=tr_data.history['loss']
    vacc=tr_data.history['val_accuracy']
    vloss=tr_data.history['val_loss']
    Epoch_count=len(tacc)+ start_epoch
    Epochs=[]
    for i in range (start_epoch ,Epoch_count):
        Epochs.append(i+1)   
    index_loss=np.argmin(vloss)#  this is the epoch with the lowest validation loss
    val_lowest=vloss[index_loss]
    index_acc=np.argmax(vacc)
    acc_highest=vacc[index_acc]
    plt.style.use('fivethirtyeight')
    sc_label='best epoch= '+ str(index_loss+1 +start_epoch)
    vc_label='best epoch= '+ str(index_acc + 1+ start_epoch)
    fig,axes=plt.subplots(nrows=1, ncols=2, figsize=(20,8))
    axes[0].plot(Epochs,tloss, 'r', label='Training loss')
    axes[0].plot(Epochs,vloss,'g',label='Validation loss' )
    axes[0].scatter(index_loss+1 +start_epoch,val_lowest, s=150, c= 'blue', label=sc_label)
    axes[0].set_title('Training and Validation Loss')
    axes[0].set_xlabel('Epochs')
    axes[0].set_ylabel('Loss')
    axes[0].legend()
    axes[1].plot (Epochs,tacc,'r',label= 'Training Accuracy')
    axes[1].plot (Epochs,vacc,'g',label= 'Validation Accuracy')
    axes[1].scatter(index_acc+1 +start_epoch,acc_highest, s=150, c= 'blue', label=vc_label)
    axes[1].set_title('Training and Validation Accuracy')
    axes[1].set_xlabel('Epochs')
    axes[1].set_ylabel('Accuracy')
    axes[1].legend()
    plt.tight_layout
    #plt.style.use('fivethirtyeight')
    plt.show()

# %%
def print_info( test_gen, preds, print_code, save_dir, subject ):
    class_dict=test_gen.class_indices
    labels= test_gen.labels
    file_names= test_gen.filenames 
    error_list=[]
    true_class=[]
    pred_class=[]
    prob_list=[]
    new_dict={}
    error_indices=[]
    y_pred=[]
    for key,value in class_dict.items():
        new_dict[value]=key             # dictionary {integer of class number: string of class name}
    # store new_dict as a text fine in the save_dir
    classes=list(new_dict.values())     # list of string of class names
    dict_as_text=str(new_dict)
    dict_name= subject + '-' +str(len(classes)) +'.txt'  
    dict_path=os.path.join(save_dir,dict_name)    
    with open(dict_path, 'w') as x_file:
        x_file.write(dict_as_text)    
    errors=0      
    for i, p in enumerate(preds):
        pred_index=np.argmax(p)        
        true_index=labels[i]  # labels are integer values
        if pred_index != true_index: # a misclassification has occurred
            error_list.append(file_names[i])
            true_class.append(new_dict[true_index])
            pred_class.append(new_dict[pred_index])
            prob_list.append(p[pred_index])
            error_indices.append(true_index)            
            errors=errors + 1
        y_pred.append(pred_index)    
    if print_code !=0:
        if errors>0:
            if print_code>errors:
                r=errors
            else:
                r=print_code           
            msg='{0:^28s}{1:^28s}{2:^28s}{3:^16s}'.format('Filename', 'Predicted Class' , 'True Class', 'Probability')
            print_in_color(msg, (0,255,0),(55,65,80))
            for i in range(r):                
                split1=os.path.split(error_list[i])                
                split2=os.path.split(split1[0])                
                fname=split2[1] + '/' + split1[1]
                msg='{0:^28s}{1:^28s}{2:^28s}{3:4s}{4:^6.4f}'.format(fname, pred_class[i],true_class[i], ' ', prob_list[i])
                print_in_color(msg, (255,255,255), (55,65,60))
                #print(error_list[i]  , pred_class[i], true_class[i], prob_list[i])               
        else:
            msg='With accuracy of 100 % there are no errors to print'
            print_in_color(msg, (0,255,0),(55,65,80))
    if errors>0:
        plot_bar=[]
        plot_class=[]
        for  key, value in new_dict.items():        
            count=error_indices.count(key) 
            if count!=0:
                plot_bar.append(count) # list containg how many times a class c had an error
                plot_class.append(value)   # stores the class 
        fig=plt.figure()
        fig.set_figheight(len(plot_class)/3)
        fig.set_figwidth(10)
        plt.style.use('fivethirtyeight')
        for i in range(0, len(plot_class)):
            c=plot_class[i]
            x=plot_bar[i]
            plt.barh(c, x, )
            plt.title( ' Errors by Class on Test Set')
    y_true= np.array(labels)        
    y_pred=np.array(y_pred)
    if len(classes)<= 36:
        # create a confusion matrix 
        cm = confusion_matrix(y_true, y_pred )        
        length=len(classes)
        if length<8:
            fig_width=8
            fig_height=8
        else:
            fig_width= int(length * .5)
            fig_height= int(length * .5)
        plt.figure(figsize=(fig_width, fig_height))
        sns.heatmap(cm, annot=True, vmin=0, fmt='g', cmap='Blues', cbar=False)       
        plt.xticks(np.arange(length)+.5, classes, rotation= 0)
        plt.yticks(np.arange(length)+.5, classes, rotation=0)
        plt.xlabel("Predicted")
        plt.ylabel("Actual")
        plt.title("Confusion Matrix")
        plt.show()
    clr = classification_report(y_true, y_pred, target_names=classes)
    print("Classification Report:\n----------------------\n", clr)

# %%
acc=model.evaluate( test_gen, batch_size=test_batch_size, verbose=1, steps=test_steps, return_dict=False)[1]*100
msg=f'accuracy on the test set is {acc:5.2f} %'

# %%
print_code=0
preds=model.predict(test_gen) 
print_info( test_gen, preds, print_code, save_dir, subject ) )

# %%
model_json = model.to_json()
with open("model_new.json", "w") as json_file:
    json_file.write(model_json)
print('Model Saved')
model.save_weights('model_new.h5')
print('Weights saved')
# Out:
# Model Saved
# Weights saved
